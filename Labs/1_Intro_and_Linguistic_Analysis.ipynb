# %% [markdown]
# ## IPython Notebook
#
# The **IPython Notebook**, or Jupyter Notebook, is an interactive computational environment, in which you can combine code execution, rich text, mathematics, plots and rich media. For more details on the Jupyter Notebook, please see the Jupyter website.
#
# ### Install
#
# ```
# pip install jupyter
# ```
#
# ### Running Jupyter
#
# You can start the dashboard on any system via the command prompt by entering the command
# ```
# jupyter notebook
# ```
# The URL for the dashboard will be something like http://localhost:8888/tree.

# %% [markdown]
# ### Cells
#
# Cells form the body of a notebook. There are two main cell types:
#
# - A **code cell** contains code to be executed in the kernel and displays its output below.
# - A **Markdown cell** contains text formatted using Markdown and displays its output in-place when it is run.

# %% [markdown]
#  # Useful links
#  [Welcome to Colab](https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=-Rh3-Vt9Nev9)
#
#   [Overview of Colab](https://colab.research.google.com/notebooks/basic_features_overview.ipynb#scrollTo=JVXnTqyE9RET)

# %% [markdown]
# # Linguistic Analysis
#
# Let's look at the different levels of linguistic analysis. First, we need some text. Let's take *Moby Dick* from Project Gutenberg, as a list of strings:

# %%
! pip install wget
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp37-none-any.whl size=9681 sha256=cf395f2d3fac90b9e768c5b73066e49c383754c50b1863fb634d09fffc42fce6
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget
url = 'https://raw.githubusercontent.com/dirkhovy/NLPclass/master/data/moby_dick.txt'
wget.download(url, 'moby_dick.txt')
# Out:
# 'moby_dick.txt'

# %%
documents = [line.strip() for line in open('moby_dick.txt', encoding='utf8').readlines()]
print(documents[1])
# Out:
# Call me Ishmael .

# %%
len(documents)
# Out:
# 9768

# %% [markdown]
# We will use the `spacy` library for a lot of the analyses. Here, we load it:

# %%
import spacy #library for advanced Natural Language Processing 

nlp = spacy.load('en') #loading the english model of spacy

# %% [markdown]
# ### Usage:
#
# We can now call `nlp()` as a function on any text. By default, it will perform a number of analyses:
# - tokenization
# - sentence splitting
# - lemmatization
# - part of speech tagging
# - dependency parsing
# - named entity recognition
#
# To speed up analysis, we can disable some of these analyses if we do not need it:
# ```
# nlp = spacy.load('en', disable=['tokenizer', 'tagger', 'parser', 'ner'])
# ```

# %% [markdown]
# The result is an iterator over the sentences (if called on a text), or tokens (if called on a sentence). Each token has a range of properties see [here](https://spacy.io/api/token#attributes). We will use a few of them in the following:
#
# - `text`: the actual word
# - `lemma_`: the dictionary entry of a word
# - `pos_`: the part of speech
# - `dep`: dependency relation
# - `is_punct`: check whether word is punctuation
# - `is_stop`: check whether word is a stop word

# %% [markdown]
# ## Tokenization
# Before we do anything, we need to insert spaces into the data.

# %%
tokens = [[token.text for token in nlp(sentence)] for sentence in documents[:100]]
#tokens

# %%
len(tokens)
# Out:
# 100

# %% [markdown]
# ### Exercise
#
# What's the longest and shortest sentence?

# %%
# your code here
import numpy as np 

len_list = list(map(len,tokens))

arg_max = np.argmax(len_list)
arg_min = np.argmin(len_list)

print(len_list[arg_max])
print(tokens[arg_max])
print(len_list[arg_min])
print(tokens[arg_min])
# Out:
# 130
# ['Though', 'I', 'can', 'not', 'tell', 'why', 'it', 'was', 'exactly', 'that', 'those', 'stage', 'managers', ',', 'the', 'Fates', ',', 'put', 'me', 'down', 'for', 'this', 'shabby', 'part', 'of', 'a', 'whaling', 'voyage', ',', 'when', 'others', 'were', 'set', 'down', 'for', 'magnificent', 'parts', 'in', 'high', 'tragedies', ',', 'and', 'short', 'and', 'easy', 'parts', 'in', 'genteel', 'comedies', ',', 'and', 'jolly', 'parts', 'in', 'farces', '--', 'though', 'I', 'can', 'not', 'tell', 'why', 'this', 'was', 'exactly', ';', 'yet', ',', 'now', 'that', 'I', 'recall', 'all', 'the', 'circumstances', ',', 'I', 'think', 'I', 'can', 'see', 'a', 'little', 'into', 'the', 'springs', 'and', 'motives', 'which', 'being', 'cunningly', 'presented', 'to', 'me', 'under', 'various', 'disguises', ',', 'induced', 'me', 'to', 'set', 'about', 'performing', 'the', 'part', 'I', 'did', ',', 'besides', 'cajoling', 'me', 'into', 'the', 'delusion', 'that', 'it', 'was', 'a', 'choice', 'resulting', 'from', 'my', 'own', 'unbiased', 'freewill', 'and', 'discriminating', 'judgment', '.']
# 2
# ['Loomings', '.']

# %% [markdown]
# ### Exercise
#
# Collect counts over the tokens. What is the most frequent token?

# %%
from collections import Counter
# your code here

count = Counter(token for sentence in tokens for token in sentence)#gives the

count.most_common(20)
# Out:
# [(',', 157),
#  ('the', 111),
#  ('.', 78),
#  ('of', 75),
#  ('a', 67),
#  ('and', 61),
#  ('to', 49),
#  ('in', 43),
#  ('I', 41),
#  ('is', 32),
#  ('that', 30),
#  ('as', 26),
#  ('--', 25),
#  ('it', 25),
#  (';', 24),
#  ('me', 23),
#  ('you', 23),
#  ('all', 21),
#  ('-', 18),
#  ('?', 18)]

# %% [markdown]
# ## Lemmatization
# We want to get the dictionary form of each word, to reduce variation.

# %%
print(documents[7])
# Out:
# There is nothing surprising in this .

# %% [markdown]
# How do you expect its lemmatize version to be?

# %%
# your code here
# word.lemma_ to lemmatize a word

for token in nlp(documents[7]):
  print(token.lemma_)
# Out:
# there
# be
# nothing
# surprising
# in
# this
# .

# %% [markdown]
# Now we run it for all the sentences

# %%
lemmas = [token.lemma_ for sentence in documents[:100] for token in nlp(sentence)]
print(len(lemmas))
lemmas[0:5]
# Out:
# 2469
# ['looming', '.', 'call', '-PRON-', 'Ishmael']

# %% [markdown]
# ### Exercise
# Right now, the lemmas of all pronouns are collapsed into `-PRON-`. Change the code to preserve the original word (as lower case).

# %%
# your code here

lemmas_with_pron = []
for sentence in documents[:100]:
  for token in nlp(sentence):
    if(token.lemma_ == "-PRON-"):
      lemmas_with_pron.append(token.lower_) #apply token.text to conervt token to a string
    else:
      lemmas_with_pron.append(token.lemma_)
lemmas_with_pron[0:5]
# Out:
# ['looming', '.', 'call', 'me', 'Ishmael']

# %% [markdown]
# ## Stemming
# A more aggressive way of removing variation is *stemming*. Let's have a look again to our example.

# %%
print(documents[7])
# Out:
# There is nothing surprising in this .

# %% [markdown]
# How do you expect the stemmed version to be?

# %%
from nltk import SnowballStemmer

stemmer = SnowballStemmer('english')
# your code here
# stemmer.stem(word) to stem a word

#my solution
#for word in documents[7].split():
#  print(stemmer.stem(word))


[stemmer.stem(token.text) for token in nlp(documents[7])]
# Out:
# ['there', 'is', 'noth', 'surpris', 'in', 'this', '.']

# %% [markdown]
# Now let's stem all our sentences

# %%
stems = [[stemmer.stem(token) for token in sentence] for sentence in tokens]
#stems

# %% [markdown]
# ### Exercise
#
# Keep track of the most frequent word for each stem in `tokens`. Hint: use a nested `defaultdict`.
#
# - How many word forms does the stem `hand` have?
# - What is the most common word form for the stems `respect` and `whale`? What happened there?

# %%
from collections import defaultdict

# your code here

stem_origins = defaultdict(lambda: defaultdict(int))

for sentence in tokens:
  for token in sentence:
    stem = stemmer.stem(token)
    stem_origins[stem][token.lower()] +=1

print(stem_origins['hand'])
print(stem_origins['respect'])
print(stem_origins['whale'])
# Out:
# defaultdict(<class 'int'>, {'hand': 3, 'handfuls': 1, 'hands': 1})
# defaultdict(<class 'int'>, {'respectable': 1, 'respectfully': 2})
# defaultdict(<class 'int'>, {'whaling': 4, 'whale': 2})

# %% [markdown]
# ## Parts of speech
# We can extract the part of speech for every word with the `pos_` atttribute.
#
# List of POS tags:
# https://universaldependencies.org/u/pos/

# %%
print(documents[7])
# Out:
# There is nothing surprising in this .

# %% [markdown]
# Which are the POS tags of these words?

# %%
# your code here
# use token.pos_
for token in nlp(documents[7]):
  print(token.text,"-->", token.pos_)
# Out:
# There --> PRON
# is --> AUX
# nothing --> PRON
# surprising --> ADJ
# in --> ADP
# this --> DET
# . --> PUNCT

# %% [markdown]
# Let's apply this to all our documents

# %%
pos = [[token.pos_ for token in nlp(sentence)] for sentence in documents[:100]]
#pos
pos[:2]
# Out:
# [['NOUN', 'PUNCT'], ['VERB', 'PRON', 'PROPN', 'PUNCT']]

# %% [markdown]
# ### Exercise
# Print out the words in the first 10 sentences, but remove all words that are not nouns, verbs, adjectives, adverbs, or proper names.

# %%
# your code here
allowed_pos = ["NOUN", 'VERB', 'ADJ', 'ADV', 'PROPN']
for sentence in documents[:10]:
  for token in nlp(sentence):
    if token.pos_ in allowed_pos:
      print(token.text,": ", token.pos_)
# Out:
# Loomings :  NOUN
# Call :  VERB
# Ishmael :  PROPN
# years :  NOUN
# ago :  ADV
# never :  ADV
# mind :  VERB
# how :  ADV
# long :  ADV
# precisely :  ADV
# having :  VERB
# little :  ADJ
# money :  NOUN
# purse :  NOUN
# particular :  ADJ
# interest :  VERB
# shore :  NOUN
# thought :  VERB
# would :  VERB
# sail :  VERB
# little :  ADJ
# see :  VERB
# watery :  ADJ
# part :  NOUN
# world :  NOUN
# way :  NOUN
# driving :  VERB
# spleen :  NOUN
# regulating :  VERB
# circulation :  NOUN
# Whenever :  ADV
# find :  VERB
# growing :  VERB
# grim :  ADJ
# mouth :  NOUN
# whenever :  ADV
# damp :  ADJ
# drizzly :  ADJ
# November :  PROPN
# soul :  NOUN
# whenever :  ADV
# find :  VERB
# involuntarily :  ADV
# pausing :  VERB
# coffin :  NOUN
# warehouses :  NOUN
# bringing :  VERB
# rear :  NOUN
# funeral :  NOUN
# meet :  VERB
# especially :  ADV
# whenever :  ADV
# hypos :  NOUN
# get :  VERB
# upper :  ADJ
# hand :  NOUN
# requires :  VERB
# strong :  ADJ
# moral :  ADJ
# principle :  NOUN
# prevent :  VERB
# deliberately :  ADV
# stepping :  VERB
# street :  NOUN
# methodically :  ADV
# knocking :  VERB
# people :  NOUN
# s :  NOUN
# hats :  NOUN
# then :  ADV
# account :  VERB
# high :  ADJ
# time :  NOUN
# sea :  NOUN
# as :  ADV
# soon :  ADV
# can :  VERB
# substitute :  NOUN
# pistol :  NOUN
# ball :  NOUN
# philosophical :  ADJ
# flourish :  ADJ
# Cato :  PROPN
# throws :  VERB
# sword :  NOUN
# quietly :  ADV
# take :  VERB
# ship :  NOUN
# surprising :  ADJ
# knew :  VERB
# almost :  ADV
# men :  NOUN
# degree :  NOUN
# time :  NOUN
# other :  ADJ
# cherish :  VERB
# very :  ADV
# nearly :  ADV
# same :  ADJ
# feelings :  NOUN
# ocean :  NOUN
# now :  ADV
# insular :  ADJ
# city :  NOUN
# Manhattoes :  PROPN
# belted :  VERB
# round :  ADV
# wharves :  NOUN
# Indian :  ADJ
# isles :  NOUN
# coral :  ADJ
# reefs :  NOUN
# commerce :  NOUN
# surrounds :  VERB
# surf :  NOUN

# %% [markdown]
# ## Named Entities
# For each noun phrase, we can infer the semantic type of it.

# %%
print(documents[9])
# Out:
# There now is your insular city of the Manhattoes , belted round by wharves as Indian isles by coral reefs -- commerce surrounds it with her surf .

# %% [markdown]
# Which are the NEs in this sentence?

# %%
# your code here
# nlp(document).ents
for token in nlp(documents[9]).ents:
  print(token.text, ": ", token.label_)

# no named entities in documents[7]
# Out:
# Manhattoes :  ORG
# Indian :  NORP

# %%
from spacy import displacy
displacy.render(nlp(documents[9]), style="ent",jupyter =True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">There now is your insular city of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Manhattoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , belted round by wharves as
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  isles by coral reefs -- commerce surrounds it with her surf .</div></span>

# %% [markdown]
# Let's apply this to all our documents

# %%
entities = [[(entity.text, entity.label_) 
             for entity in nlp(sentence).ents]
            for sentence in documents[:50]]
#entities
#nlp('John gave a book to Mary and Celia in Cardiff').ents

# %% [markdown]
# ### Exercise
# Who are the 5 most frequently named people in the first 500 sentence?

# %%
# your code here
#persons = [entity.text for entity in nlp(sentence).ents for sentence in documents[:500] if entity.label_ == 'PERSON']

persons = []
for sentence in documents[:500]:
  for entity in nlp(sentence).ents:
    if entity.label_ == 'PERSON':
      persons.append(entity.text)
Counter(persons).most_common(5)
# Out:
# [('Queequeg', 17), ('don', 4), ('Nantucket', 2), ('Jonah', 2), ('Sal', 2)]

# %% [markdown]
# ### Exercise
#
# Use the text below to extract all entities.
# - Create tuples of `(lemma, NER type)`
# - Collect counts over the tuples
# - Look at the 10 most frequent tuples: how many of them are wrong? Why? Discuss with a neighbor.

# %%
text = """
Seville.
Summers in the flamboyant Andalucían capital often nudge 40C, but spring is a delight, with the parks in bloom and the scent of orange blossom and jasmine in the air. And in Semana Santa (Holy Week, 14-20 April) the streets come alive with floats and processions. There is also the raucous annual Feria de Abril – a week-long fiesta of parades, flamenco and partying long into the night (4-11 May; expect higher hotel prices if you visit then).
Seville is a romantic and energetic place, with sights aplenty, from the Unesco-listed cathedral – the largest Gothic cathedral in the world – to the beautiful Alcázar royal palace. But days here are best spent simply wandering the medieval streets of Santa Cruz and along the river to La Real Maestranza, Spain’s most spectacular bullring.
Seville is the birthplace of tapas and perfect for a foodie break – join a tapas tour (try devoursevillefoodtours.com), or stop at the countless bars for a glass of sherry with local jamón ibérico (check out Bar Las Teresas in Santa Cruz or historic Casa Morales in Constitución). Great food markets include the Feria, the oldest, and the wooden, futuristic-looking Metropol Parasol.
Nightlife is, unsurprisingly, late and lively. For flamenco, try one of the peñas, or flamenco social clubs – Torres Macarena on C/Torrijano, perhaps – with bars open across town until the early hours.
Book it: In an atmospheric 18th-century house, the Hospes Casa del Rey de Baeza is a lovely place to stay in lively Santa Cruz. Doubles from £133 room only, hospes.com
Trieste.
By April, temperatures are on the rise in Trieste and in the late 20s by May. It is far less touristy than the likes of Florence or Rome, and spring sees the city’s lovely restaurants and bars populated almost exclusively by locals.
A city with a proud coffee-drinking culture – Illy has its headquarters here – Trieste has many venerable cafes, including the dazzling mirror-walled Caffè degli Specchi on the Piazza Unità d’Italia – said to be Europe’s biggest seaside piazza – and the elegant Caffè San Marco, which has a good bookshop. James Joyce was a regular when he lived here between 1904-1915. You can learn all about him at the excellent museum, which also has a free, downloadable themed walk on its website (museojoycetrieste.it).
Above Trieste is a vast limestone plateau known as the carso (or karst). Travel up to Villa Opicina on the edge of the region by bus.
There are several trattorie, but for a real treat catch a cab to one of the 30 or so osmize – farm restaurants that sell their wines, cured meats, cheese, honey, fruit and veg; traditionally, they were open eight, 16 or 24 days per year (“osmi” means “eighth” in Slovene) but this now varies – check the app at osmize.com for details.
Book it: Stay at the palatial, seafront Savoia Excelsior Palace, Jan Morris’s pad in her book Trieste and the Meaning of Nowhere. Doubles from £127 room only, starhotelscollezione.com
Belgrade.
As Belgrade shrugs off the snow, cafe tables start colonising the pavements again. Not that Serbia’s capital hibernates during the winter, but spring brings a freshness worth savouring before summer’s 40C heat kicks in.
You feel it especially in Kalemegdan, the huge park and fortress hugging the confluence of the Danube and Sava rivers. Down below are wide riverside paths that offer superb cycling all the way to the attractive suburb of Zemun. Follow the Sava southwards to reach the river island of Ada Ciganlija – open all year round for walks and bike rides and usually warm enough in May for a swim.
Although barely a month goes by without a festival, the pace picks up during spring. The Belgrade Dance Festival attracts dance companies from around the world. Classical guitar gets its own spotlight during the Guitar Art Festivalfrom 12-17 March, and from 26-28 April you can join the Orthodox Easter festivities. The landmark Mikser House in Savamala may have closed, but its Mikser festival still celebrates the best in Balkan design (24-26 May).
With the long-awaited reopening of the National Museum of Serbia and the Museum of Contemporary Art, Belgrade has some cultural heavyweights to add to its dizzyingly varied restaurant scene. Head to the Dorćol district for cheap cocktails in Blaznavac’s psychedelic garden before a Balkan-Mediterranean dinner in cosy Tezga (Strahinjića Bana 82, on Facebook).
Book it: Set in a handsome 1929 villa in Dorćol, Smokvica has six stylish rooms as well as a restaurant with a courtyard garden. Doubles from €70 room only, smokvica.rs
Montpellier.
Montpellier combines easy elegance and a vibrant cultural scene with a youthful buzz – its university, founded in the 13th century, counts radical satirist Rabelais among its alumni and some 60,000 students live here.
The medieval centre is a maze made for wandering, with 16 leafy squares – in spring, all green and abuzz with alfresco cafe life. The vast, pedestrianised Place de la Comédie connects the old town with the striking new Antigone district, replete with modern, neoclassical-style buildings.
For a fine-art foray, head to Musée Fabre – one of the biggest in France – or nearby photography museum Pavillon Populaire. Montpellier boasts the oldest botanical garden in France, too, dating from 1593 and particularly beautiful in April and May. Independent boutiques, opera houses, markets laden with Languedoc produce (look for oysters and asparagus) and great dining options add to the appeal. Le Petit Jardin is a bistro and lovely garden restaurant near the old cathedral.
Beyond the city, discover vineyards like Mas de Daumas Gassac or hike up Pic St-Loup in the Cévennes foothills for views over the coast. The beach and charming seaside town of Palavas-les-Flots is just 10km away – a tram ride or easy cycle (rent bicycles from Ville et Vélo).
Book it: Hotel Le Guilhem is a 16th-century building in the historic centre with cathedral views from its terrace (where breakfast is served, weather permitting). Doubles from £83 room only, leguilhem.com
Berlin.
After a long, cold winter, Berliners waste no time in celebrating the return of the sun, with beer gardens and flea markets reopening all over the city. Try picturesque Cafe Am Neuen Seefor lakeside pizza and beer in the Tiergarten, and hang out with the hipsters along the canal at Berlin’s coolest flohmarkt, surrounded by cherry blossom trees, a charming place to browse and have a couple of beers.
For the best blossom, though, head to one of the trails along the line of the wall, the Mauerweg, near S-bahn Bornholmer Strasse, or Lichterfelde Süd, where the trees were gifted by the Japanese to celebrate German reunification in 1989.
Berlin is set for two big anniversaries this year: it’s 100 years since the Bauhaus was founded and 30 years since the wall came down, so check out events including exhibitions and dances themed around the former (see visitberlin.de for more information) or get a feel for the creative chaos of post-wall Berlin at the multimedia Nineties Berlin exhibition.
Boat tours along the river and canals are superb in spring but, generally, cycling is the best way to get around (many hotels and hostels have their own). And if urban life gets a bit much, do as the Berliners do and head out to one of the many city lakes, such as Schlachtensee or Wannsee, directly accessible by U and S-bahn.
Book it: Boutique Hotel Oderberger in a trendy, central location has doubles from £113, hotel-oderberger.berlin, or try indoor caravanning at Hüttenpalast, doubles from £61 room only, huettenpalast.de
"""

# your code here

doc = nlp(text)
tokens = [(entity.lemma_ , entity.label_) for entity in doc.ents]
Counter(tokens).most_common(10)
# Out:
# [(('one', 'CARDINAL'), 5),
#  (('Berlin', 'GPE'), 4),
#  (('Seville', 'ORG'), 3),
#  (('Santa Cruz', 'GPE'), 3),
#  (('Belgrade', 'GPE'), 3),
#  (('April', 'DATE'), 2),
#  (('winter', 'DATE'), 2),
#  (('Sava', 'ORG'), 2),
#  (('spring', 'DATE'), 2),
#  (('France', 'GPE'), 2)]

# %% [markdown]
# ## Parsing
# For each word, we can extract the word it is grammatically related to, plus the type of the relation.

# %%
print(documents[7])
# Out:
# There is nothing surprising in this .

# %% [markdown]
# Which are the NEs in this sentence?

# %%
# your code here
for token in nlp(documents[7]):
  print(token.text, token.head.text, token.dep_)
# Out:
# There is expl
# is is ROOT
# nothing is attr
# surprising nothing amod
# in surprising prep
# this in pobj
# . is punct

# %%
displacy.render(nlp(documents[7]), style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4f803fe1f08b4a0288f85f59f6e0c2c1-0" class="displacy" width="1100" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">There</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">nothing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">surprising</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">this .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">expl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-2" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,91.5 L583.0,79.5 567.0,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-3" stroke-width="2px" d="M595,89.5 C595,2.0 750.0,2.0 750.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,91.5 L758.0,79.5 742.0,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-4" stroke-width="2px" d="M770,89.5 C770,2.0 925.0,2.0 925.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f803fe1f08b4a0288f85f59f6e0c2c1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,91.5 L933.0,79.5 917.0,79.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Let's apply this to all our documents

# %%
[[(c.text, c.head.text, c.dep_) for c in nlp(sentence)] 
 for sentence in documents[:100]]
# Out:
# [[('Loomings', 'Loomings', 'ROOT'), ('.', 'Loomings', 'punct')],
#  [('Call', 'Call', 'ROOT'),
#   ('me', 'Call', 'dobj'),
#   ('Ishmael', 'Call', 'oprd'),
#   ('.', 'Call', 'punct')],
#  [('Some', 'years', 'det'),
#   ('years', 'ago', 'npadvmod'),
#   ('ago', 'ago', 'ROOT'),
#   ('--', 'ago', 'punct'),
#   ('never', 'mind', 'neg'),
#   ('mind', 'ago', 'intj'),
#   ('how', 'long', 'advmod'),
#   ('long', 'precisely', 'advmod'),
#   ('precisely', 'mind', 'advmod'),
#   ('--', 'having', 'punct'),
#   ('having', 'thought', 'advcl'),
#   ('little', 'money', 'amod'),
#   ('or', 'little', 'cc'),
#   ('no', 'little', 'conj'),
#   ('money', 'having', 'dobj'),
#   ('in', 'having', 'prep'),
#   ('my', 'purse', 'poss'),
#   ('purse', 'in', 'pobj'),
#   (',', 'having', 'punct'),
#   ('and', 'having', 'cc'),
#   ('nothing', 'interest', 'nsubj'),
#   ('particular', 'nothing', 'amod'),
#   ('to', 'interest', 'aux'),
#   ('interest', 'having', 'conj'),
#   ('me', 'interest', 'dobj'),
#   ('on', 'interest', 'prep'),
#   ('shore', 'on', 'pobj'),
#   (',', 'thought', 'punct'),
#   ('I', 'thought', 'nsubj'),
#   ('thought', 'thought', 'ROOT'),
#   ('I', 'sail', 'nsubj'),
#   ('would', 'sail', 'aux'),
#   ('sail', 'thought', 'ccomp'),
#   ('about', 'little', 'advmod'),
#   ('a', 'little', 'det'),
#   ('little', 'sail', 'dobj'),
#   ('and', 'sail', 'cc'),
#   ('see', 'sail', 'conj'),
#   ('the', 'part', 'det'),
#   ('watery', 'part', 'amod'),
#   ('part', 'see', 'dobj'),
#   ('of', 'part', 'prep'),
#   ('the', 'world', 'det'),
#   ('world', 'of', 'pobj'),
#   ('.', 'thought', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('a', 'way', 'det'),
#   ('way', 'is', 'attr'),
#   ('I', 'have', 'nsubj'),
#   ('have', 'way', 'relcl'),
#   ('of', 'way', 'prep'),
#   ('driving', 'of', 'pcomp'),
#   ('off', 'driving', 'prt'),
#   ('the', 'spleen', 'det'),
#   ('spleen', 'driving', 'dobj'),
#   ('and', 'driving', 'cc'),
#   ('regulating', 'driving', 'conj'),
#   ('the', 'circulation', 'det'),
#   ('circulation', 'regulating', 'dobj'),
#   ('.', 'is', 'punct')],
#  [('Whenever', 'find', 'advmod'),
#   ('I', 'find', 'nsubj'),
#   ('find', 'find', 'advcl'),
#   ('myself', 'growing', 'nsubj'),
#   ('growing', 'find', 'ccomp'),
#   ('grim', 'growing', 'acomp'),
#   ('about', 'grim', 'prep'),
#   ('the', 'mouth', 'det'),
#   ('mouth', 'about', 'pobj'),
#   (';', 'find', 'punct'),
#   ('whenever', 'is', 'advmod'),
#   ('it', 'is', 'nsubj'),
#   ('is', 'drizzly', 'advcl'),
#   ('a', 'damp', 'det'),
#   ('damp', 'is', 'attr'),
#   (',', 'drizzly', 'punct'),
#   ('drizzly', 'find', 'ccomp'),
#   ('November', 'drizzly', 'npadvmod'),
#   ('in', 'drizzly', 'prep'),
#   ('my', 'soul', 'poss'),
#   ('soul', 'in', 'pobj'),
#   (';', 'find', 'punct'),
#   ('whenever', 'find', 'advmod'),
#   ('I', 'find', 'nsubj'),
#   ('find', 'requires', 'ccomp'),
#   ('myself', 'pausing', 'nsubj'),
#   ('involuntarily', 'pausing', 'advmod'),
#   ('pausing', 'find', 'ccomp'),
#   ('before', 'pausing', 'prep'),
#   ('coffin', 'warehouses', 'compound'),
#   ('warehouses', 'before', 'pobj'),
#   (',', 'find', 'punct'),
#   ('and', 'find', 'cc'),
#   ('bringing', 'find', 'conj'),
#   ('up', 'bringing', 'prt'),
#   ('the', 'rear', 'det'),
#   ('rear', 'bringing', 'dobj'),
#   ('of', 'rear', 'prep'),
#   ('every', 'funeral', 'det'),
#   ('funeral', 'of', 'pobj'),
#   ('I', 'meet', 'nsubj'),
#   ('meet', 'funeral', 'relcl'),
#   (';', 'bringing', 'punct'),
#   ('and', 'bringing', 'cc'),
#   ('especially', 'get', 'advmod'),
#   ('whenever', 'get', 'advmod'),
#   ('my', 'hypos', 'poss'),
#   ('hypos', 'get', 'nsubj'),
#   ('get', 'bringing', 'conj'),
#   ('such', 'hand', 'predet'),
#   ('an', 'hand', 'det'),
#   ('upper', 'hand', 'amod'),
#   ('hand', 'get', 'dobj'),
#   ('of', 'hand', 'prep'),
#   ('me', 'of', 'pobj'),
#   (',', 'requires', 'punct'),
#   ('that', 'requires', 'mark'),
#   ('it', 'requires', 'nsubj'),
#   ('requires', 'account', 'ccomp'),
#   ('a', 'principle', 'det'),
#   ('strong', 'principle', 'amod'),
#   ('moral', 'principle', 'amod'),
#   ('principle', 'requires', 'dobj'),
#   ('to', 'prevent', 'aux'),
#   ('prevent', 'requires', 'xcomp'),
#   ('me', 'prevent', 'dobj'),
#   ('from', 'prevent', 'prep'),
#   ('deliberately', 'stepping', 'advmod'),
#   ('stepping', 'from', 'pcomp'),
#   ('into', 'stepping', 'prep'),
#   ('the', 'street', 'det'),
#   ('street', 'into', 'pobj'),
#   (',', 'requires', 'punct'),
#   ('and', 'requires', 'cc'),
#   ('methodically', 'knocking', 'advmod'),
#   ('knocking', 'requires', 'conj'),
#   ('people', 's', 'poss'),
#   ("'", 'people', 'case'),
#   ('s', 'knocking', 'dobj'),
#   ('hats', 'knocking', 'dobj'),
#   ('off', 'hats', 'prt'),
#   ('--', 'account', 'punct'),
#   ('then', 'account', 'advmod'),
#   (',', 'account', 'punct'),
#   ('I', 'account', 'nsubj'),
#   ('account', 'account', 'ROOT'),
#   ('it', 'account', 'dobj'),
#   ('high', 'time', 'amod'),
#   ('time', 'account', 'npadvmod'),
#   ('to', 'get', 'aux'),
#   ('get', 'account', 'advcl'),
#   ('to', 'get', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'soon', 'advmod'),
#   ('soon', 'get', 'advmod'),
#   ('as', 'can', 'mark'),
#   ('I', 'can', 'nsubj'),
#   ('can', 'soon', 'advcl'),
#   ('.', 'account', 'punct')],
#  [('This', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('my', 'substitute', 'poss'),
#   ('substitute', 'is', 'attr'),
#   ('for', 'substitute', 'prep'),
#   ('pistol', 'for', 'pobj'),
#   ('and', 'pistol', 'cc'),
#   ('ball', 'pistol', 'conj'),
#   ('.', 'is', 'punct')],
#  [('With', 'throws', 'prep'),
#   ('a', 'flourish', 'det'),
#   ('philosophical', 'flourish', 'amod'),
#   ('flourish', 'With', 'pobj'),
#   ('Cato', 'throws', 'nsubj'),
#   ('throws', 'take', 'ccomp'),
#   ('himself', 'throws', 'dobj'),
#   ('upon', 'throws', 'prep'),
#   ('his', 'sword', 'poss'),
#   ('sword', 'upon', 'pobj'),
#   (';', 'take', 'punct'),
#   ('I', 'take', 'nsubj'),
#   ('quietly', 'take', 'advmod'),
#   ('take', 'take', 'ROOT'),
#   ('to', 'take', 'prep'),
#   ('the', 'ship', 'det'),
#   ('ship', 'to', 'pobj'),
#   ('.', 'take', 'punct')],
#  [('There', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('nothing', 'is', 'attr'),
#   ('surprising', 'nothing', 'amod'),
#   ('in', 'surprising', 'prep'),
#   ('this', 'in', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('If', 'knew', 'mark'),
#   ('they', 'knew', 'nsubj'),
#   ('but', 'they', 'cc'),
#   ('knew', 'cherish', 'advcl'),
#   ('it', 'knew', 'dobj'),
#   (',', 'cherish', 'punct'),
#   ('almost', 'all', 'advmod'),
#   ('all', 'men', 'nummod'),
#   ('men', 'cherish', 'nsubj'),
#   ('in', 'men', 'prep'),
#   ('their', 'degree', 'poss'),
#   ('degree', 'in', 'pobj'),
#   (',', 'men', 'punct'),
#   ('some', 'time', 'det'),
#   ('time', 'men', 'appos'),
#   ('or', 'time', 'cc'),
#   ('other', 'time', 'conj'),
#   (',', 'cherish', 'punct'),
#   ('cherish', 'cherish', 'ROOT'),
#   ('very', 'nearly', 'advmod'),
#   ('nearly', 'cherish', 'advmod'),
#   ('the', 'feelings', 'det'),
#   ('same', 'feelings', 'amod'),
#   ('feelings', 'cherish', 'dobj'),
#   ('towards', 'feelings', 'prep'),
#   ('the', 'ocean', 'det'),
#   ('ocean', 'towards', 'pobj'),
#   ('with', 'cherish', 'prep'),
#   ('me', 'with', 'pobj'),
#   ('.', 'cherish', 'punct')],
#  [('There', 'is', 'expl'),
#   ('now', 'is', 'advmod'),
#   ('is', 'surrounds', 'ccomp'),
#   ('your', 'city', 'poss'),
#   ('insular', 'city', 'amod'),
#   ('city', 'is', 'attr'),
#   ('of', 'city', 'prep'),
#   ('the', 'Manhattoes', 'det'),
#   ('Manhattoes', 'of', 'pobj'),
#   (',', 'is', 'punct'),
#   ('belted', 'is', 'conj'),
#   ('round', 'belted', 'advmod'),
#   ('by', 'belted', 'agent'),
#   ('wharves', 'by', 'pobj'),
#   ('as', 'wharves', 'prep'),
#   ('Indian', 'isles', 'amod'),
#   ('isles', 'as', 'pobj'),
#   ('by', 'belted', 'agent'),
#   ('coral', 'reefs', 'amod'),
#   ('reefs', 'by', 'pobj'),
#   ('--', 'surrounds', 'punct'),
#   ('commerce', 'surrounds', 'nsubj'),
#   ('surrounds', 'surrounds', 'ROOT'),
#   ('it', 'surrounds', 'dobj'),
#   ('with', 'surrounds', 'prep'),
#   ('her', 'surf', 'poss'),
#   ('surf', 'with', 'pobj'),
#   ('.', 'surrounds', 'punct')],
#  [('Right', 'take', 'intj'),
#   ('and', 'Right', 'cc'),
#   ('left', 'Right', 'conj'),
#   (',', 'take', 'punct'),
#   ('the', 'streets', 'det'),
#   ('streets', 'take', 'nsubj'),
#   ('take', 'take', 'ROOT'),
#   ('you', 'take', 'dobj'),
#   ('waterward', 'take', 'advmod'),
#   ('.', 'take', 'punct')],
#  [('Its', 'downtown', 'poss'),
#   ('extreme', 'downtown', 'amod'),
#   ('downtown', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('the', 'battery', 'det'),
#   ('battery', 'is', 'attr'),
#   (',', 'battery', 'punct'),
#   ('where', 'washed', 'advmod'),
#   ('that', 'mole', 'det'),
#   ('noble', 'mole', 'amod'),
#   ('mole', 'washed', 'nsubjpass'),
#   ('is', 'washed', 'auxpass'),
#   ('washed', 'battery', 'relcl'),
#   ('by', 'washed', 'agent'),
#   ('waves', 'by', 'pobj'),
#   (',', 'washed', 'punct'),
#   ('and', 'washed', 'cc'),
#   ('cooled', 'washed', 'conj'),
#   ('by', 'cooled', 'agent'),
#   ('breezes', 'by', 'pobj'),
#   (',', 'breezes', 'punct'),
#   ('which', 'were', 'nsubj'),
#   ('a', 'hours', 'det'),
#   ('few', 'hours', 'amod'),
#   ('hours', 'previous', 'npadvmod'),
#   ('previous', 'were', 'acomp'),
#   ('were', 'breezes', 'relcl'),
#   ('out', 'were', 'prep'),
#   ('of', 'out', 'prep'),
#   ('sight', 'of', 'pobj'),
#   ('of', 'sight', 'prep'),
#   ('land', 'of', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('Look', 'Look', 'ROOT'),
#   ('at', 'Look', 'prep'),
#   ('the', 'crowds', 'det'),
#   ('crowds', 'at', 'pobj'),
#   ('of', 'crowds', 'prep'),
#   ('water', 'gazers', 'compound'),
#   ('-', 'gazers', 'punct'),
#   ('gazers', 'of', 'pobj'),
#   ('there', 'crowds', 'advmod'),
#   ('.', 'Look', 'punct')],
#  [('Circumambulate', 'Circumambulate', 'ROOT'),
#   ('the', 'city', 'det'),
#   ('city', 'Circumambulate', 'dobj'),
#   ('of', 'city', 'prep'),
#   ('a', 'afternoon', 'det'),
#   ('dreamy', 'afternoon', 'amod'),
#   ('Sabbath', 'afternoon', 'compound'),
#   ('afternoon', 'of', 'pobj'),
#   ('.', 'Circumambulate', 'punct')],
#  [('Go', 'Go', 'ROOT'),
#   ('from', 'Go', 'prep'),
#   ('Corlears', 'Hook', 'compound'),
#   ('Hook', 'from', 'pobj'),
#   ('to', 'Go', 'prep'),
#   ('Coenties', 'Slip', 'compound'),
#   ('Slip', 'to', 'pobj'),
#   (',', 'Go', 'punct'),
#   ('and', 'Go', 'cc'),
#   ('from', 'Go', 'conj'),
#   ('thence', 'from', 'pobj'),
#   (',', 'from', 'punct'),
#   ('by', 'from', 'prep'),
#   ('Whitehall', 'by', 'pobj'),
#   (',', 'from', 'punct'),
#   ('northward', 'from', 'npadvmod'),
#   ('.', 'Go', 'punct')],
#  [('What', 'see', 'dobj'),
#   ('do', 'see', 'aux'),
#   ('you', 'see', 'nsubj'),
#   ('see', 'see', 'ROOT'),
#   ('?', 'see', 'punct'),
#   ('--', 'Posted', 'punct'),
#   ('Posted', 'Posted', 'ROOT'),
#   ('like', 'Posted', 'prep'),
#   ('silent', 'sentinels', 'amod'),
#   ('sentinels', 'like', 'pobj'),
#   ('all', 'around', 'advmod'),
#   ('around', 'sentinels', 'prep'),
#   ('the', 'town', 'det'),
#   ('town', 'around', 'pobj'),
#   (',', 'Posted', 'punct'),
#   ('stand', 'Posted', 'dep'),
#   ('thousands', 'stand', 'npadvmod'),
#   ('upon', 'stand', 'prep'),
#   ('thousands', 'upon', 'pobj'),
#   ('of', 'thousands', 'prep'),
#   ('mortal', 'men', 'amod'),
#   ('men', 'of', 'pobj'),
#   ('fixed', 'men', 'acl'),
#   ('in', 'fixed', 'prep'),
#   ('ocean', 'reveries', 'compound'),
#   ('reveries', 'in', 'pobj'),
#   ('.', 'Posted', 'punct')],
#  [('Some', 'leaning', 'nsubj'),
#   ('leaning', 'seated', 'ccomp'),
#   ('against', 'leaning', 'prep'),
#   ('the', 'spiles', 'det'),
#   ('spiles', 'against', 'pobj'),
#   (';', 'seated', 'punct'),
#   ('some', 'seated', 'nsubj'),
#   ('seated', 'seated', 'ROOT'),
#   ('upon', 'seated', 'prep'),
#   ('the', 'heads', 'det'),
#   ('pier', 'heads', 'compound'),
#   ('-', 'heads', 'punct'),
#   ('heads', 'upon', 'pobj'),
#   (';', 'seated', 'punct'),
#   ('some', 'looking', 'nsubj'),
#   ('looking', 'seated', 'conj'),
#   ('over', 'looking', 'prep'),
#   ('the', 'bulwarks', 'det'),
#   ('bulwarks', 'over', 'pobj'),
#   ('of', 'bulwarks', 'prep'),
#   ('ships', 'of', 'pobj'),
#   ('from', 'ships', 'prep'),
#   ('China', 'from', 'pobj'),
#   (';', 'looking', 'punct'),
#   ('some', 'aloft', 'advmod'),
#   ('high', 'aloft', 'amod'),
#   ('aloft', 'looking', 'advmod'),
#   ('in', 'aloft', 'prep'),
#   ('the', 'rigging', 'det'),
#   ('rigging', 'in', 'pobj'),
#   (',', 'aloft', 'punct'),
#   ('as', 'striving', 'mark'),
#   ('if', 'striving', 'mark'),
#   ('striving', 'looking', 'advcl'),
#   ('to', 'get', 'aux'),
#   ('get', 'striving', 'xcomp'),
#   ('a', 'peep', 'det'),
#   ('still', 'better', 'advmod'),
#   ('better', 'peep', 'amod'),
#   ('seaward', 'peep', 'compound'),
#   ('peep', 'get', 'dobj'),
#   ('.', 'seated', 'punct')],
#  [('But', 'are', 'cc'),
#   ('these', 'are', 'nsubj'),
#   ('are', 'are', 'ROOT'),
#   ('all', 'are', 'dep'),
#   ('landsmen', 'are', 'attr'),
#   (';', 'are', 'punct'),
#   ('of', 'are', 'prep'),
#   ('week', 'days', 'compound'),
#   ('days', 'pent', 'npadvmod'),
#   ('pent', 'pent', 'ROOT'),
#   ('up', 'pent', 'prt'),
#   ('in', 'pent', 'prep'),
#   ('lath', 'in', 'pobj'),
#   ('and', 'lath', 'cc'),
#   ('plaster', 'lath', 'conj'),
#   ('--', 'pent', 'punct'),
#   ('tied', 'pent', 'advcl'),
#   ('to', 'tied', 'prep'),
#   ('counters', 'to', 'pobj'),
#   (',', 'tied', 'punct'),
#   ('nailed', 'pent', 'conj'),
#   ('to', 'nailed', 'prep'),
#   ('benches', 'to', 'pobj'),
#   (',', 'nailed', 'punct'),
#   ('clinched', 'nailed', 'conj'),
#   ('to', 'clinched', 'prep'),
#   ('desks', 'to', 'pobj'),
#   ('.', 'pent', 'punct')],
#  [('How', 'then', 'advmod'),
#   ('then', 'is', 'advmod'),
#   ('is', 'is', 'ROOT'),
#   ('this', 'is', 'nsubj'),
#   ('?', 'is', 'punct')],
#  [('Are', 'gone', 'auxpass'),
#   ('the', 'fields', 'det'),
#   ('green', 'fields', 'amod'),
#   ('fields', 'gone', 'nsubj'),
#   ('gone', 'gone', 'ROOT'),
#   ('?', 'gone', 'punct')],
#  [('What', 'do', 'nsubj'),
#   ('do', 'do', 'ROOT'),
#   ('they', 'do', 'nsubj'),
#   ('here', 'do', 'advmod'),
#   ('?', 'do', 'punct')],
#  [('But', 'look', 'cc'), ('look', 'look', 'ROOT'), ('!', 'look', 'punct')],
#  [('here', 'come', 'advmod'),
#   ('come', 'come', 'ROOT'),
#   ('more', 'crowds', 'amod'),
#   ('crowds', 'come', 'nsubj'),
#   (',', 'come', 'punct'),
#   ('pacing', 'come', 'advcl'),
#   ('straight', 'for', 'advmod'),
#   ('for', 'pacing', 'prep'),
#   ('the', 'water', 'det'),
#   ('water', 'for', 'pobj'),
#   (',', 'pacing', 'punct'),
#   ('and', 'pacing', 'cc'),
#   ('seemingly', 'bound', 'advmod'),
#   ('bound', 'pacing', 'conj'),
#   ('for', 'bound', 'prep'),
#   ('a', 'dive', 'det'),
#   ('dive', 'for', 'pobj'),
#   ('.', 'come', 'punct')],
#  [('Strange', 'Strange', 'ROOT'), ('!', 'Strange', 'punct')],
#  [('Nothing', 'content', 'nsubj'),
#   ('will', 'content', 'aux'),
#   ('content', 'suffice', 'ccomp'),
#   ('them', 'content', 'dobj'),
#   ('but', 'content', 'cc'),
#   ('the', 'limit', 'det'),
#   ('extremest', 'limit', 'amod'),
#   ('limit', 'content', 'conj'),
#   ('of', 'limit', 'prep'),
#   ('the', 'land', 'det'),
#   ('land', 'of', 'pobj'),
#   (';', 'suffice', 'punct'),
#   ('loitering', 'suffice', 'nsubj'),
#   ('under', 'loitering', 'prep'),
#   ('the', 'lee', 'det'),
#   ('shady', 'lee', 'amod'),
#   ('lee', 'under', 'pobj'),
#   ('of', 'lee', 'prep'),
#   ('yonder', 'warehouses', 'compound'),
#   ('warehouses', 'of', 'pobj'),
#   ('will', 'suffice', 'aux'),
#   ('not', 'suffice', 'neg'),
#   ('suffice', 'suffice', 'ROOT'),
#   ('.', 'suffice', 'punct')],
#  [('No', 'No', 'ROOT'), ('.', 'No', 'punct')],
#  [('They', 'get', 'nsubj'),
#   ('must', 'get', 'aux'),
#   ('get', 'get', 'ROOT'),
#   ('just', 'nigh', 'advmod'),
#   ('as', 'nigh', 'mark'),
#   ('nigh', 'get', 'dobj'),
#   ('the', 'water', 'det'),
#   ('water', 'nigh', 'appos'),
#   ('as', 'can', 'mark'),
#   ('they', 'can', 'nsubj'),
#   ('possibly', 'can', 'advmod'),
#   ('can', 'get', 'advcl'),
#   ('without', 'get', 'prep'),
#   ('falling', 'without', 'pcomp'),
#   ('in', 'falling', 'prt'),
#   ('.', 'get', 'punct')],
#  [('And', 'stand', 'cc'),
#   ('there', 'stand', 'advmod'),
#   ('they', 'stand', 'nsubj'),
#   ('stand', 'stand', 'ROOT'),
#   ('--', 'stand', 'punct'),
#   ('miles', 'stand', 'npadvmod'),
#   ('of', 'miles', 'prep'),
#   ('them', 'of', 'pobj'),
#   ('--', 'miles', 'punct'),
#   ('leagues', 'miles', 'appos'),
#   ('.', 'stand', 'punct')],
#  [('Inlanders', 'come', 'advcl'),
#   ('all', 'Inlanders', 'appos'),
#   (',', 'come', 'punct'),
#   ('they', 'come', 'nsubj'),
#   ('come', 'come', 'ROOT'),
#   ('from', 'come', 'prep'),
#   ('lanes', 'from', 'pobj'),
#   ('and', 'lanes', 'cc'),
#   ('alleys', 'lanes', 'conj'),
#   (',', 'lanes', 'punct'),
#   ('streets', 'lanes', 'conj'),
#   ('and', 'streets', 'cc'),
#   ('avenues', 'streets', 'conj'),
#   ('--', 'lanes', 'punct'),
#   ('north', 'lanes', 'appos'),
#   (',', 'north', 'punct'),
#   ('east', 'north', 'conj'),
#   (',', 'east', 'punct'),
#   ('south', 'east', 'conj'),
#   (',', 'south', 'punct'),
#   ('and', 'south', 'cc'),
#   ('west', 'south', 'conj'),
#   ('.', 'come', 'punct')],
#  [('Yet', 'unite', 'advmod'),
#   ('here', 'unite', 'advmod'),
#   ('they', 'unite', 'nsubj'),
#   ('all', 'they', 'appos'),
#   ('unite', 'unite', 'ROOT'),
#   ('.', 'unite', 'punct')],
#  [('Tell', 'Tell', 'ROOT'),
#   ('me', 'Tell', 'dobj'),
#   (',', 'Tell', 'punct'),
#   ('does', 'attract', 'aux'),
#   ('the', 'virtue', 'det'),
#   ('magnetic', 'virtue', 'amod'),
#   ('virtue', 'attract', 'nsubj'),
#   ('of', 'virtue', 'prep'),
#   ('the', 'needles', 'det'),
#   ('needles', 'of', 'pobj'),
#   ('of', 'needles', 'prep'),
#   ('the', 'compasses', 'det'),
#   ('compasses', 'of', 'pobj'),
#   ('of', 'compasses', 'prep'),
#   ('all', 'ships', 'predet'),
#   ('those', 'ships', 'det'),
#   ('ships', 'of', 'pobj'),
#   ('attract', 'Tell', 'ccomp'),
#   ('them', 'attract', 'dobj'),
#   ('thither', 'attract', 'advmod'),
#   ('?', 'Tell', 'punct')],
#  [('Once', 'more', 'advmod'),
#   ('more', 'more', 'ROOT'),
#   ('.', 'more', 'punct')],
#  [('Say', 'Say', 'ROOT'),
#   ('you', 'are', 'nsubj'),
#   ('are', 'Say', 'ccomp'),
#   ('in', 'are', 'prep'),
#   ('the', 'country', 'det'),
#   ('country', 'in', 'pobj'),
#   (';', 'Say', 'punct'),
#   ('in', 'Say', 'prep'),
#   ('some', 'land', 'det'),
#   ('high', 'land', 'amod'),
#   ('land', 'in', 'pobj'),
#   ('of', 'land', 'prep'),
#   ('lakes', 'of', 'pobj'),
#   ('.', 'Say', 'punct')],
#  [('Take', 'Take', 'ROOT'),
#   ('almost', 'any', 'advmod'),
#   ('any', 'path', 'nummod'),
#   ('path', 'Take', 'dobj'),
#   ('you', 'please', 'nsubj'),
#   ('please', 'path', 'relcl'),
#   (',', 'Take', 'punct'),
#   ('and', 'Take', 'cc'),
#   ('ten', 'carries', 'npadvmod'),
#   ('to', 'ten', 'prep'),
#   ('one', 'to', 'pobj'),
#   ('it', 'carries', 'nsubj'),
#   ('carries', 'Take', 'conj'),
#   ('you', 'carries', 'dobj'),
#   ('down', 'carries', 'prt'),
#   ('in', 'carries', 'prep'),
#   ('a', 'dale', 'det'),
#   ('dale', 'in', 'pobj'),
#   (',', 'carries', 'punct'),
#   ('and', 'carries', 'cc'),
#   ('leaves', 'carries', 'conj'),
#   ('you', 'leaves', 'dobj'),
#   ('there', 'leaves', 'advmod'),
#   ('by', 'leaves', 'prep'),
#   ('a', 'pool', 'det'),
#   ('pool', 'by', 'pobj'),
#   ('in', 'pool', 'prep'),
#   ('the', 'stream', 'det'),
#   ('stream', 'in', 'pobj'),
#   ('.', 'carries', 'punct')],
#  [('There', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('magic', 'is', 'attr'),
#   ('in', 'is', 'prep'),
#   ('it', 'in', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('Let', 'Let', 'ROOT'),
#   ('the', 'minded', 'det'),
#   ('most', 'absent', 'advmod'),
#   ('absent', 'minded', 'amod'),
#   ('-', 'minded', 'punct'),
#   ('minded', 'plunged', 'nsubjpass'),
#   ('of', 'minded', 'prep'),
#   ('men', 'of', 'pobj'),
#   ('be', 'plunged', 'auxpass'),
#   ('plunged', 'Let', 'ccomp'),
#   ('in', 'plunged', 'prep'),
#   ('his', 'reveries', 'poss'),
#   ('deepest', 'reveries', 'amod'),
#   ('reveries', 'in', 'pobj'),
#   ('--', 'plunged', 'punct'),
#   ('stand', 'Let', 'ccomp'),
#   ('that', 'man', 'det'),
#   ('man', 'stand', 'dobj'),
#   ('on', 'stand', 'prep'),
#   ('his', 'legs', 'poss'),
#   ('legs', 'on', 'pobj'),
#   (',', 'stand', 'punct'),
#   ('set', 'stand', 'conj'),
#   ('his', 'feet', 'poss'),
#   ('feet', 'set', 'dobj'),
#   ('a', 'going', 'det'),
#   ('-', 'going', 'punct'),
#   ('going', 'set', 'advcl'),
#   (',', 'Let', 'punct'),
#   ('and', 'Let', 'cc'),
#   ('he', 'lead', 'nsubj'),
#   ('will', 'lead', 'aux'),
#   ('infallibly', 'lead', 'advmod'),
#   ('lead', 'Let', 'conj'),
#   ('you', 'lead', 'dobj'),
#   ('to', 'lead', 'prep'),
#   ('water', 'to', 'pobj'),
#   (',', 'lead', 'punct'),
#   ('if', 'be', 'mark'),
#   ('water', 'be', 'nsubj'),
#   ('there', 'water', 'advmod'),
#   ('be', 'lead', 'advcl'),
#   ('in', 'be', 'prep'),
#   ('all', 'region', 'predet'),
#   ('that', 'region', 'det'),
#   ('region', 'in', 'pobj'),
#   ('.', 'lead', 'punct')],
#  [('Should', 'be', 'aux'),
#   ('you', 'be', 'nsubj'),
#   ('ever', 'be', 'advmod'),
#   ('be', 'be', 'ROOT'),
#   ('athirst', 'be', 'attr'),
#   ('in', 'be', 'prep'),
#   ('the', 'desert', 'det'),
#   ('great', 'desert', 'amod'),
#   ('American', 'desert', 'amod'),
#   ('desert', 'in', 'pobj'),
#   (',', 'be', 'punct'),
#   ('try', 'be', 'conj'),
#   ('this', 'experiment', 'det'),
#   ('experiment', 'try', 'dobj'),
#   (',', 'try', 'punct'),
#   ('if', 'happen', 'mark'),
#   ('your', 'caravan', 'poss'),
#   ('caravan', 'happen', 'nsubj'),
#   ('happen', 'try', 'advcl'),
#   ('to', 'supplied', 'aux'),
#   ('be', 'supplied', 'auxpass'),
#   ('supplied', 'happen', 'xcomp'),
#   ('with', 'supplied', 'prep'),
#   ('a', 'professor', 'det'),
#   ('metaphysical', 'professor', 'amod'),
#   ('professor', 'with', 'pobj'),
#   ('.', 'be', 'punct')],
#  [('Yes', 'wedded', 'intj'),
#   (',', 'wedded', 'punct'),
#   ('as', 'knows', 'mark'),
#   ('every', 'one', 'det'),
#   ('one', 'knows', 'nsubj'),
#   ('knows', 'wedded', 'advcl'),
#   (',', 'wedded', 'punct'),
#   ('meditation', 'wedded', 'nsubjpass'),
#   ('and', 'meditation', 'cc'),
#   ('water', 'meditation', 'conj'),
#   ('are', 'wedded', 'auxpass'),
#   ('wedded', 'wedded', 'ROOT'),
#   ('for', 'wedded', 'prep'),
#   ('ever', 'for', 'pcomp'),
#   ('.', 'wedded', 'punct')],
#  [('But', 'is', 'cc'),
#   ('here', 'is', 'advmod'),
#   ('is', 'is', 'ROOT'),
#   ('an', 'artist', 'det'),
#   ('artist', 'is', 'attr'),
#   ('.', 'is', 'punct')],
#  [('He', 'desires', 'nsubj'),
#   ('desires', 'desires', 'ROOT'),
#   ('to', 'paint', 'aux'),
#   ('paint', 'desires', 'xcomp'),
#   ('you', 'paint', 'dative'),
#   ('the', 'quietest', 'det'),
#   ('dreamiest', 'quietest', 'amod'),
#   (',', 'quietest', 'punct'),
#   ('shadiest', 'quietest', 'amod'),
#   (',', 'shadiest', 'punct'),
#   ('quietest', 'paint', 'dobj'),
#   (',', 'quietest', 'punct'),
#   ('most', 'enchanting', 'advmod'),
#   ('enchanting', 'bit', 'amod'),
#   ('bit', 'quietest', 'appos'),
#   ('of', 'bit', 'prep'),
#   ('romantic', 'landscape', 'amod'),
#   ('landscape', 'of', 'pobj'),
#   ('in', 'quietest', 'prep'),
#   ('all', 'valley', 'predet'),
#   ('the', 'valley', 'det'),
#   ('valley', 'in', 'pobj'),
#   ('of', 'valley', 'prep'),
#   ('the', 'Saco', 'det'),
#   ('Saco', 'of', 'pobj'),
#   ('.', 'desires', 'punct')],
#  [('What', 'is', 'attr'),
#   ('is', 'is', 'ROOT'),
#   ('the', 'element', 'det'),
#   ('chief', 'element', 'amod'),
#   ('element', 'is', 'nsubj'),
#   ('he', 'employs', 'nsubj'),
#   ('employs', 'element', 'relcl'),
#   ('?', 'is', 'punct')],
#  [('There', 'stand', 'expl'),
#   ('stand', 'stand', 'ROOT'),
#   ('his', 'trees', 'poss'),
#   ('trees', 'stand', 'dobj'),
#   (',', 'trees', 'punct'),
#   ('each', 'trees', 'appos'),
#   ('with', 'each', 'prep'),
#   ('a', 'trunk', 'det'),
#   ('hollow', 'trunk', 'amod'),
#   ('trunk', 'with', 'pobj'),
#   (',', 'stand', 'punct'),
#   ('as', 'were', 'mark'),
#   ('if', 'were', 'mark'),
#   ('a', 'hermit', 'det'),
#   ('hermit', 'were', 'nsubj'),
#   ('and', 'hermit', 'cc'),
#   ('a', 'crucifix', 'det'),
#   ('crucifix', 'hermit', 'conj'),
#   ('were', 'stand', 'advcl'),
#   ('within', 'were', 'acomp'),
#   (';', 'stand', 'punct'),
#   ('and', 'stand', 'cc'),
#   ('here', 'sleeps', 'advmod'),
#   ('sleeps', 'stand', 'conj'),
#   ('his', 'meadow', 'poss'),
#   ('meadow', 'sleeps', 'dobj'),
#   (',', 'sleeps', 'punct'),
#   ('and', 'sleeps', 'cc'),
#   ('there', 'sleep', 'expl'),
#   ('sleep', 'sleeps', 'conj'),
#   ('his', 'cattle', 'poss'),
#   ('cattle', 'sleep', 'dobj'),
#   (';', 'sleep', 'punct'),
#   ('and', 'sleep', 'cc'),
#   ('up', 'goes', 'prep'),
#   ('from', 'up', 'prep'),
#   ('yonder', 'cottage', 'compound'),
#   ('cottage', 'from', 'pobj'),
#   ('goes', 'sleep', 'conj'),
#   ('a', 'smoke', 'det'),
#   ('sleepy', 'smoke', 'amod'),
#   ('smoke', 'goes', 'dobj'),
#   ('.', 'sleeps', 'punct')],
#  [('Deep', 'into', 'advmod'),
#   ('into', 'winds', 'prep'),
#   ('distant', 'woodlands', 'amod'),
#   ('woodlands', 'into', 'pobj'),
#   ('winds', 'winds', 'ROOT'),
#   ('a', 'way', 'det'),
#   ('mazy', 'way', 'compound'),
#   ('way', 'winds', 'dobj'),
#   (',', 'winds', 'punct'),
#   ('reaching', 'winds', 'advcl'),
#   ('to', 'reaching', 'prep'),
#   ('overlapping', 'spurs', 'amod'),
#   ('spurs', 'to', 'pobj'),
#   ('of', 'spurs', 'prep'),
#   ('mountains', 'of', 'pobj'),
#   ('bathed', 'mountains', 'acl'),
#   ('in', 'bathed', 'prep'),
#   ('their', 'blue', 'poss'),
#   ('hill', 'side', 'compound'),
#   ('-', 'side', 'punct'),
#   ('side', 'blue', 'compound'),
#   ('blue', 'in', 'pobj'),
#   ('.', 'winds', 'punct')],
#  [('But', 'tranced', 'cc'),
#   ('though', 'lies', 'mark'),
#   ('the', 'picture', 'det'),
#   ('picture', 'lies', 'nsubj'),
#   ('lies', 'tranced', 'advcl'),
#   ('thus', 'tranced', 'advmod'),
#   ('tranced', 'tranced', 'ROOT'),
#   (',', 'tranced', 'punct'),
#   ('and', 'tranced', 'cc'),
#   ('though', 'shakes', 'mark'),
#   ('this', 'tree', 'det'),
#   ('pine', 'tree', 'compound'),
#   ('-', 'tree', 'punct'),
#   ('tree', 'shakes', 'nsubj'),
#   ('shakes', 'tranced', 'conj'),
#   ('down', 'shakes', 'prt'),
#   ('its', 'sighs', 'poss'),
#   ('sighs', 'shakes', 'dobj'),
#   ('like', 'sighs', 'prep'),
#   ('leaves', 'like', 'pobj'),
#   ('upon', 'leaves', 'prep'),
#   ('this', 'shepherd', 'det'),
#   ('shepherd', 'head', 'poss'),
#   ("'", 'shepherd', 'punct'),
#   ('s', 'head', 'compound'),
#   ('head', 'upon', 'pobj'),
#   (',', 'shakes', 'punct'),
#   ('yet', 'shakes', 'cc'),
#   ('all', 'were', 'nsubj'),
#   ('were', 'shakes', 'conj'),
#   ('vain', 'were', 'acomp'),
#   (',', 'were', 'punct'),
#   ('unless', 'fixed', 'mark'),
#   ('the', 'shepherd', 'det'),
#   ('shepherd', 'eye', 'poss'),
#   ("'", 'shepherd', 'case'),
#   ('s', 'shepherd', 'case'),
#   ('eye', 'fixed', 'nsubjpass'),
#   ('were', 'fixed', 'auxpass'),
#   ('fixed', 'were', 'advcl'),
#   ('upon', 'fixed', 'prep'),
#   ('the', 'stream', 'det'),
#   ('magic', 'stream', 'amod'),
#   ('stream', 'upon', 'pobj'),
#   ('before', 'stream', 'prep'),
#   ('him', 'before', 'pobj'),
#   ('.', 'shakes', 'punct')],
#  [('Go', 'visit', 'aux'),
#   ('visit', 'visit', 'ROOT'),
#   ('the', 'Prairies', 'det'),
#   ('Prairies', 'visit', 'dobj'),
#   ('in', 'visit', 'prep'),
#   ('June', 'in', 'pobj'),
#   (',', 'visit', 'punct'),
#   ('when', 'wade', 'advmod'),
#   ('for', 'wade', 'prep'),
#   ('scores', 'for', 'pobj'),
#   ('on', 'scores', 'prep'),
#   ('scores', 'on', 'pobj'),
#   ('of', 'scores', 'prep'),
#   ('miles', 'of', 'pobj'),
#   ('you', 'wade', 'nsubj'),
#   ('wade', 'is', 'advcl'),
#   ('knee', 'deep', 'compound'),
#   ('-', 'deep', 'punct'),
#   ('deep', 'wade', 'dobj'),
#   ('among', 'deep', 'prep'),
#   ('Tiger', 'lilies', 'compound'),
#   ('-', 'lilies', 'punct'),
#   ('lilies', 'among', 'pobj'),
#   ('--', 'is', 'punct'),
#   ('what', 'is', 'attr'),
#   ('is', 'wanting', 'aux'),
#   ('the', 'charm', 'det'),
#   ('one', 'charm', 'nummod'),
#   ('charm', 'wanting', 'nsubj'),
#   ('wanting', 'wanting', 'ROOT'),
#   ('?', 'wanting', 'punct'),
#   ('--', 'is', 'punct'),
#   ('Water', 'is', 'npadvmod'),
#   ('--', 'is', 'punct'),
#   ('there', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('not', 'is', 'neg'),
#   ('a', 'drop', 'det'),
#   ('drop', 'is', 'attr'),
#   ('of', 'drop', 'prep'),
#   ('water', 'of', 'pobj'),
#   ('there', 'drop', 'advmod'),
#   ('!', 'is', 'punct')],
#  [('Were', 'travel', 'advcl'),
#   ('Niagara', 'Were', 'nsubj'),
#   ('but', 'Niagara', 'cc'),
#   ('a', 'cataract', 'det'),
#   ('cataract', 'Niagara', 'conj'),
#   ('of', 'cataract', 'prep'),
#   ('sand', 'of', 'pobj'),
#   (',', 'travel', 'punct'),
#   ('would', 'travel', 'aux'),
#   ('you', 'travel', 'nsubj'),
#   ('travel', 'travel', 'ROOT'),
#   ('your', 'miles', 'poss'),
#   ('thousand', 'miles', 'nummod'),
#   ('miles', 'travel', 'dobj'),
#   ('to', 'see', 'aux'),
#   ('see', 'travel', 'advcl'),
#   ('it', 'see', 'dobj'),
#   ('?', 'travel', 'punct')],
#  [('Why', 'deliberate', 'advmod'),
#   ('did', 'deliberate', 'aux'),
#   ('the', 'poet', 'det'),
#   ('poor', 'poet', 'amod'),
#   ('poet', 'deliberate', 'nsubj'),
#   ('of', 'poet', 'prep'),
#   ('Tennessee', 'of', 'pobj'),
#   (',', 'deliberate', 'punct'),
#   ('upon', 'deliberate', 'prep'),
#   ('suddenly', 'receiving', 'advmod'),
#   ('receiving', 'upon', 'pcomp'),
#   ('two', 'handfuls', 'nummod'),
#   ('handfuls', 'receiving', 'dobj'),
#   ('of', 'handfuls', 'prep'),
#   ('silver', 'of', 'pobj'),
#   (',', 'deliberate', 'punct'),
#   ('deliberate', 'deliberate', 'ROOT'),
#   ('whether', 'buy', 'mark'),
#   ('to', 'buy', 'aux'),
#   ('buy', 'deliberate', 'advcl'),
#   ('him', 'buy', 'dative'),
#   ('a', 'coat', 'det'),
#   ('coat', 'buy', 'dobj'),
#   (',', 'coat', 'punct'),
#   ('which', 'needed', 'dobj'),
#   ('he', 'needed', 'nsubj'),
#   ('sadly', 'needed', 'advmod'),
#   ('needed', 'coat', 'relcl'),
#   (',', 'needed', 'punct'),
#   ('or', 'needed', 'cc'),
#   ('invest', 'needed', 'conj'),
#   ('his', 'money', 'poss'),
#   ('money', 'invest', 'dobj'),
#   ('in', 'invest', 'prep'),
#   ('a', 'trip', 'det'),
#   ('pedestrian', 'trip', 'compound'),
#   ('trip', 'in', 'pobj'),
#   ('to', 'trip', 'prep'),
#   ('Rockaway', 'Beach', 'compound'),
#   ('Beach', 'to', 'pobj'),
#   ('?', 'deliberate', 'punct')],
#  [('Why', 'is', 'advmod'),
#   ('is', 'is', 'ROOT'),
#   ('almost', 'every', 'advmod'),
#   ('every', 'boy', 'nummod'),
#   ('robust', 'healthy', 'advmod'),
#   ('healthy', 'boy', 'amod'),
#   ('boy', 'is', 'nsubj'),
#   ('with', 'boy', 'prep'),
#   ('a', 'soul', 'det'),
#   ('robust', 'healthy', 'advmod'),
#   ('healthy', 'soul', 'amod'),
#   ('soul', 'with', 'pobj'),
#   ('in', 'soul', 'prep'),
#   ('him', 'in', 'pobj'),
#   (',', 'is', 'punct'),
#   ('at', ',', 'intj'),
#   ('some', 'time', 'det'),
#   ('time', 'at', 'pobj'),
#   ('or', 'time', 'cc'),
#   ('other', 'at', 'conj'),
#   ('crazy', 'at', 'amod'),
#   ('to', 'go', 'aux'),
#   ('go', 'is', 'advcl'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('?', 'is', 'punct')],
#  [('Why', 'feel', 'advmod'),
#   ('upon', 'feel', 'prep'),
#   ('your', 'voyage', 'poss'),
#   ('first', 'voyage', 'amod'),
#   ('voyage', 'upon', 'pobj'),
#   ('as', 'voyage', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   (',', 'feel', 'punct'),
#   ('did', 'feel', 'aux'),
#   ('you', 'feel', 'nsubj'),
#   ('yourself', 'you', 'appos'),
#   ('feel', 'feel', 'ROOT'),
#   ('such', 'vibration', 'predet'),
#   ('a', 'vibration', 'det'),
#   ('mystical', 'vibration', 'amod'),
#   ('vibration', 'feel', 'dobj'),
#   (',', 'feel', 'punct'),
#   ('when', 'told', 'advmod'),
#   ('first', 'told', 'advmod'),
#   ('told', 'feel', 'advcl'),
#   ('that', 'were', 'mark'),
#   ('you', 'were', 'nsubj'),
#   ('and', 'you', 'cc'),
#   ('your', 'ship', 'poss'),
#   ('ship', 'you', 'conj'),
#   ('were', 'told', 'ccomp'),
#   ('now', 'were', 'advmod'),
#   ('out', 'were', 'prep'),
#   ('of', 'out', 'prep'),
#   ('sight', 'of', 'pobj'),
#   ('of', 'sight', 'prep'),
#   ('land', 'of', 'pobj'),
#   ('?', 'feel', 'punct')],
#  [('Why', 'hold', 'advmod'),
#   ('did', 'hold', 'aux'),
#   ('the', 'Persians', 'det'),
#   ('old', 'Persians', 'amod'),
#   ('Persians', 'hold', 'nsubj'),
#   ('hold', 'hold', 'ROOT'),
#   ('the', 'sea', 'det'),
#   ('sea', 'holy', 'nsubj'),
#   ('holy', 'hold', 'ccomp'),
#   ('?', 'hold', 'punct')],
#  [('Why', 'give', 'advmod'),
#   ('did', 'give', 'aux'),
#   ('the', 'Greeks', 'det'),
#   ('Greeks', 'give', 'nsubj'),
#   ('give', 'give', 'ROOT'),
#   ('it', 'give', 'dative'),
#   ('a', 'deity', 'det'),
#   ('separate', 'deity', 'amod'),
#   ('deity', 'give', 'dobj'),
#   (',', 'give', 'punct'),
#   ('and', 'give', 'cc'),
#   ('own', 'brother', 'amod'),
#   ('brother', 'give', 'conj'),
#   ('of', 'brother', 'prep'),
#   ('Jove', 'of', 'pobj'),
#   ('?', 'give', 'punct')],
#  [('Surely', 'is', 'advmod'),
#   ('all', 'this', 'predet'),
#   ('this', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('not', 'is', 'neg'),
#   ('without', 'is', 'prep'),
#   ('meaning', 'without', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('And', 'deeper', 'cc'),
#   ('still', 'deeper', 'advmod'),
#   ('deeper', 'deeper', 'ROOT'),
#   ('the', 'meaning', 'det'),
#   ('meaning', 'deeper', 'dobj'),
#   ('of', 'meaning', 'prep'),
#   ('that', 'story', 'det'),
#   ('story', 'of', 'pobj'),
#   ('of', 'story', 'prep'),
#   ('Narcissus', 'of', 'pobj'),
#   (',', 'story', 'punct'),
#   ('who', 'plunged', 'nsubj'),
#   ('because', 'grasp', 'mark'),
#   ('he', 'grasp', 'nsubj'),
#   ('could', 'grasp', 'aux'),
#   ('not', 'grasp', 'neg'),
#   ('grasp', 'plunged', 'advcl'),
#   ('the', 'tormenting', 'det'),
#   ('tormenting', 'grasp', 'dobj'),
#   (',', 'plunged', 'punct'),
#   ('mild', 'image', 'amod'),
#   ('image', 'plunged', 'nsubj'),
#   ('he', 'saw', 'nsubj'),
#   ('saw', 'image', 'relcl'),
#   ('in', 'saw', 'prep'),
#   ('the', 'fountain', 'det'),
#   ('fountain', 'in', 'pobj'),
#   (',', 'image', 'punct'),
#   ('plunged', 'story', 'relcl'),
#   ('into', 'plunged', 'prep'),
#   ('it', 'into', 'pobj'),
#   ('and', 'plunged', 'cc'),
#   ('was', 'drowned', 'auxpass'),
#   ('drowned', 'plunged', 'conj'),
#   ('.', 'deeper', 'punct')],
#  [('But', 'see', 'cc'),
#   ('that', 'image', 'det'),
#   ('same', 'image', 'amod'),
#   ('image', 'see', 'npadvmod'),
#   (',', 'see', 'punct'),
#   ('we', 'see', 'nsubj'),
#   ('ourselves', 'we', 'appos'),
#   ('see', 'see', 'ROOT'),
#   ('in', 'see', 'prep'),
#   ('all', 'rivers', 'det'),
#   ('rivers', 'in', 'pobj'),
#   ('and', 'rivers', 'cc'),
#   ('oceans', 'rivers', 'conj'),
#   ('.', 'see', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('the', 'image', 'det'),
#   ('image', 'is', 'attr'),
#   ('of', 'image', 'prep'),
#   ('the', 'phantom', 'det'),
#   ('ungraspable', 'phantom', 'amod'),
#   ('phantom', 'of', 'pobj'),
#   ('of', 'phantom', 'prep'),
#   ('life', 'of', 'pobj'),
#   (';', 'is', 'punct'),
#   ('and', 'is', 'cc'),
#   ('this', 'is', 'nsubj'),
#   ('is', 'is', 'conj'),
#   ('the', 'key', 'det'),
#   ('key', 'is', 'attr'),
#   ('to', 'key', 'prep'),
#   ('it', 'to', 'pobj'),
#   ('all', 'it', 'appos'),
#   ('.', 'is', 'punct')],
#  [('Now', 'mean', 'advmod'),
#   (',', 'mean', 'punct'),
#   ('when', 'say', 'advmod'),
#   ('I', 'say', 'nsubj'),
#   ('say', 'mean', 'advcl'),
#   ('that', 'am', 'mark'),
#   ('I', 'am', 'nsubj'),
#   ('am', 'say', 'ccomp'),
#   ('in', 'am', 'prep'),
#   ('the', 'habit', 'det'),
#   ('habit', 'in', 'pobj'),
#   ('of', 'habit', 'prep'),
#   ('going', 'of', 'pcomp'),
#   ('to', 'going', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('whenever', 'begin', 'advmod'),
#   ('I', 'begin', 'nsubj'),
#   ('begin', 'going', 'advcl'),
#   ('to', 'grow', 'aux'),
#   ('grow', 'begin', 'xcomp'),
#   ('hazy', 'grow', 'dobj'),
#   ('about', 'hazy', 'prep'),
#   ('the', 'eyes', 'det'),
#   ('eyes', 'about', 'pobj'),
#   (',', 'am', 'punct'),
#   ('and', 'am', 'cc'),
#   ('begin', 'am', 'conj'),
#   ('to', 'be', 'aux'),
#   ('be', 'begin', 'xcomp'),
#   ('over', 'conscious', 'advmod'),
#   ('conscious', 'be', 'acomp'),
#   ('of', 'conscious', 'prep'),
#   ('my', 'lungs', 'poss'),
#   ('lungs', 'of', 'pobj'),
#   (',', 'mean', 'punct'),
#   ('I', 'mean', 'nsubj'),
#   ('do', 'mean', 'aux'),
#   ('not', 'mean', 'neg'),
#   ('mean', 'mean', 'ROOT'),
#   ('to', 'have', 'aux'),
#   ('have', 'mean', 'xcomp'),
#   ('it', 'inferred', 'nsubj'),
#   ('inferred', 'have', 'ccomp'),
#   ('that', 'go', 'mark'),
#   ('I', 'go', 'nsubj'),
#   ('ever', 'go', 'advmod'),
#   ('go', 'inferred', 'ccomp'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'go', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   ('.', 'mean', 'punct')],
#  [('For', 'have', 'prep'),
#   ('to', 'go', 'aux'),
#   ('go', 'For', 'pcomp'),
#   ('as', 'go', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   ('you', 'needs', 'nsubj'),
#   ('must', 'needs', 'aux'),
#   ('needs', 'passenger', 'relcl'),
#   ('have', 'have', 'ROOT'),
#   ('a', 'purse', 'det'),
#   ('purse', 'have', 'dobj'),
#   (',', 'have', 'punct'),
#   ('and', 'have', 'cc'),
#   ('a', 'purse', 'det'),
#   ('purse', 'is', 'nsubj'),
#   ('is', 'have', 'conj'),
#   ('but', 'is', 'cc'),
#   ('a', 'rag', 'det'),
#   ('rag', 'is', 'conj'),
#   ('unless', 'have', 'mark'),
#   ('you', 'have', 'nsubj'),
#   ('have', 'is', 'advcl'),
#   ('something', 'have', 'dobj'),
#   ('in', 'something', 'prep'),
#   ('it', 'in', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('Besides', 'get', 'advmod'),
#   (',', 'get', 'punct'),
#   ('passengers', 'get', 'nsubj'),
#   ('get', 'get', 'ROOT'),
#   ('sea', 'sick', 'compound'),
#   ('-', 'sick', 'punct'),
#   ('sick', 'get', 'acomp'),
#   ('--', 'get', 'punct'),
#   ('grow', 'get', 'ccomp'),
#   ('quarrelsome', 'grow', 'acomp'),
#   ('--', 'grow', 'punct'),
#   ('don', 'sleep', 'poss'),
#   ("'", 'don', 'case'),
#   ('t', 'sleep', 'compound'),
#   ('sleep', 'grow', 'npadvmod'),
#   ('of', 'sleep', 'prep'),
#   ('nights', 'of', 'pobj'),
#   ('--', 'grow', 'punct'),
#   ('do', 'enjoy', 'aux'),
#   ('not', 'enjoy', 'neg'),
#   ('enjoy', 'get', 'conj'),
#   ('themselves', 'enjoy', 'dobj'),
#   ('much', 'enjoy', 'advmod'),
#   (',', 'enjoy', 'punct'),
#   ('as', 'enjoy', 'prep'),
#   ('a', 'thing', 'det'),
#   ('general', 'thing', 'amod'),
#   ('thing', 'as', 'pobj'),
#   (';', 'enjoy', 'punct'),
#   ('--', 'enjoy', 'punct'),
#   ('no', 'go', 'intj'),
#   (',', 'go', 'punct'),
#   ('I', 'go', 'nsubj'),
#   ('never', 'go', 'neg'),
#   ('go', 'go', 'ROOT'),
#   ('as', 'go', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   (';', 'go', 'punct'),
#   ('nor', 'go', 'cc'),
#   (',', 'go', 'punct'),
#   ('though', 'am', 'mark'),
#   ('I', 'am', 'nsubj'),
#   ('am', 'go', 'advcl'),
#   ('something', 'am', 'attr'),
#   ('of', 'something', 'prep'),
#   ('a', 'salt', 'det'),
#   ('salt', 'of', 'pobj'),
#   (',', 'go', 'punct'),
#   ('do', 'go', 'aux'),
#   ('I', 'go', 'nsubj'),
#   ('ever', 'go', 'advmod'),
#   ('go', 'go', 'conj'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'go', 'prep'),
#   ('a', 'Commodore', 'det'),
#   ('Commodore', 'as', 'pobj'),
#   (',', 'Commodore', 'punct'),
#   ('or', 'Commodore', 'cc'),
#   ('a', 'Captain', 'det'),
#   ('Captain', 'Commodore', 'conj'),
#   (',', 'Captain', 'punct'),
#   ('or', 'Captain', 'cc'),
#   ('a', 'Cook', 'det'),
#   ('Cook', 'Captain', 'conj'),
#   ('.', 'go', 'punct')],
#  [('I', 'abandon', 'nsubj'),
#   ('abandon', 'abandon', 'ROOT'),
#   ('the', 'glory', 'det'),
#   ('glory', 'abandon', 'dobj'),
#   ('and', 'glory', 'cc'),
#   ('distinction', 'glory', 'conj'),
#   ('of', 'glory', 'prep'),
#   ('such', 'offices', 'amod'),
#   ('offices', 'of', 'pobj'),
#   ('to', 'abandon', 'dative'),
#   ('those', 'to', 'pobj'),
#   ('who', 'like', 'nsubj'),
#   ('like', 'those', 'relcl'),
#   ('them', 'like', 'dobj'),
#   ('.', 'abandon', 'punct')],
#  [('For', 'abominate', 'prep'),
#   ('my', 'part', 'poss'),
#   ('part', 'For', 'pobj'),
#   (',', 'abominate', 'punct'),
#   ('I', 'abominate', 'nsubj'),
#   ('abominate', 'abominate', 'ROOT'),
#   ('all', 'honourable', 'advmod'),
#   ('honourable', 'abominate', 'xcomp'),
#   ('respectable', 'toils', 'amod'),
#   ('toils', 'honourable', 'npadvmod'),
#   (',', 'toils', 'punct'),
#   ('trials', 'toils', 'conj'),
#   (',', 'trials', 'punct'),
#   ('and', 'trials', 'cc'),
#   ('tribulations', 'trials', 'conj'),
#   ('of', 'toils', 'prep'),
#   ('every', 'kind', 'det'),
#   ('kind', 'of', 'pobj'),
#   ('whatsoever', 'kind', 'advmod'),
#   ('.', 'abominate', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('quite', 'much', 'advmod'),
#   ('as', 'much', 'advmod'),
#   ('much', 'is', 'attr'),
#   ('as', 'do', 'mark'),
#   ('I', 'do', 'nsubj'),
#   ('can', 'do', 'aux'),
#   ('do', 'much', 'advcl'),
#   ('to', 'take', 'aux'),
#   ('take', 'is', 'xcomp'),
#   ('care', 'take', 'dobj'),
#   ('of', 'take', 'prep'),
#   ('myself', 'of', 'pobj'),
#   (',', 'take', 'punct'),
#   ('without', 'take', 'prep'),
#   ('taking', 'without', 'pcomp'),
#   ('care', 'taking', 'dobj'),
#   ('of', 'taking', 'prep'),
#   ('ships', 'of', 'pobj'),
#   (',', 'ships', 'punct'),
#   ('barques', 'ships', 'conj'),
#   (',', 'barques', 'punct'),
#   ('brigs', 'barques', 'conj'),
#   (',', 'brigs', 'punct'),
#   ('schooners', 'brigs', 'conj'),
#   (',', 'schooners', 'punct'),
#   ('and', 'schooners', 'cc'),
#   ('what', 'schooners', 'conj'),
#   ('not', 'is', 'neg'),
#   ('.', 'is', 'punct')],
#  [('And', 'is', 'cc'),
#   ('as', 'is', 'prep'),
#   ('for', 'as', 'prep'),
#   ('going', 'for', 'pcomp'),
#   ('as', 'going', 'prep'),
#   ('cook', 'as', 'pobj'),
#   (',', 'is', 'punct'),
#   ('--', 'is', 'punct'),
#   ('though', 'confess', 'mark'),
#   ('I', 'confess', 'nsubj'),
#   ('confess', 'is', 'advcl'),
#   ('there', 'is', 'expl'),
#   ('is', 'is', 'ccomp'),
#   ('considerable', 'glory', 'amod'),
#   ('glory', 'is', 'attr'),
#   ('in', 'glory', 'prep'),
#   ('that', 'in', 'pobj'),
#   (',', 'glory', 'punct'),
#   ('a', 'cook', 'det'),
#   ('cook', 'glory', 'appos'),
#   ('being', 'cook', 'acl'),
#   ('a', 'sort', 'det'),
#   ('sort', 'being', 'attr'),
#   ('of', 'sort', 'prep'),
#   ('officer', 'of', 'pobj'),
#   ('on', 'sort', 'prep'),
#   ('ship', 'board', 'compound'),
#   ('-', 'board', 'punct'),
#   ('board', 'on', 'pobj'),
#   ('--', 'is', 'punct'),
#   ('yet', 'is', 'advmod'),
#   (',', 'is', 'punct'),
#   ('somehow', 'fancied', 'advmod'),
#   (',', 'fancied', 'punct'),
#   ('I', 'fancied', 'nsubj'),
#   ('never', 'fancied', 'neg'),
#   ('fancied', 'is', 'conj'),
#   ('broiling', 'fowls', 'compound'),
#   ('fowls', 'fancied', 'dobj'),
#   (';', 'fancied', 'punct'),
#   ('--', 'is', 'punct'),
#   ('though', 'broiled', 'mark'),
#   ('once', 'broiled', 'advmod'),
#   ('broiled', 'buttered', 'advcl'),
#   (',', 'buttered', 'punct'),
#   ('judiciously', 'buttered', 'advmod'),
#   ('buttered', 'is', 'conj'),
#   (',', 'buttered', 'punct'),
#   ('and', 'buttered', 'cc'),
#   ('judgmatically', 'salted', 'advmod'),
#   ('salted', 'buttered', 'conj'),
#   ('and', 'salted', 'cc'),
#   ('peppered', 'salted', 'conj'),
#   (',', 'is', 'punct'),
#   ('there', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('no', 'one', 'det'),
#   ('one', 'is', 'attr'),
#   ('who', 'speak', 'nsubj'),
#   ('will', 'speak', 'aux'),
#   ('speak', 'one', 'relcl'),
#   ('more', 'respectfully', 'advmod'),
#   ('respectfully', 'speak', 'advmod'),
#   (',', 'speak', 'punct'),
#   ('not', 'say', 'neg'),
#   ('to', 'say', 'aux'),
#   ('say', 'speak', 'dep'),
#   ('reverentially', 'say', 'advmod'),
#   (',', 'say', 'punct'),
#   ('of', 'say', 'prep'),
#   ('a', 'fowl', 'det'),
#   ('broiled', 'fowl', 'amod'),
#   ('fowl', 'of', 'pobj'),
#   ('than', 'will', 'mark'),
#   ('I', 'will', 'nsubj'),
#   ('will', 'fowl', 'advcl'),
#   ('.', 'is', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('out', 'is', 'prep'),
#   ('of', 'out', 'prep'),
#   ('the', 'dotings', 'det'),
#   ('idolatrous', 'dotings', 'amod'),
#   ('dotings', 'of', 'pobj'),
#   ('of', 'dotings', 'prep'),
#   ('the', 'Egyptians', 'det'),
#   ('old', 'Egyptians', 'amod'),
#   ('Egyptians', 'of', 'pobj'),
#   ('upon', 'dotings', 'prep'),
#   ('broiled', 'ibis', 'amod'),
#   ('ibis', 'upon', 'pobj'),
#   ('and', 'ibis', 'cc'),
#   ('roasted', 'horse', 'amod'),
#   ('river', 'horse', 'compound'),
#   ('horse', 'ibis', 'conj'),
#   (',', 'is', 'punct'),
#   ('that', 'see', 'mark'),
#   ('you', 'see', 'nsubj'),
#   ('see', 'is', 'ccomp'),
#   ('the', 'mummies', 'det'),
#   ('mummies', 'see', 'dobj'),
#   ('of', 'mummies', 'prep'),
#   ('those', 'creatures', 'det'),
#   ('creatures', 'of', 'pobj'),
#   ('in', 'mummies', 'prep'),
#   ('their', 'houses', 'poss'),
#   ('huge', 'houses', 'amod'),
#   ('bake', 'houses', 'compound'),
#   ('-', 'houses', 'punct'),
#   ('houses', 'in', 'pobj'),
#   ('the', 'pyramids', 'det'),
#   ('pyramids', 'mummies', 'appos'),
#   ('.', 'is', 'punct')],
#  [('No', 'go', 'intj'),
#   (',', 'go', 'punct'),
#   ('when', 'go', 'advmod'),
#   ('I', 'go', 'nsubj'),
#   ('go', 'go', 'advcl'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   (',', 'go', 'punct'),
#   ('I', 'go', 'nsubj'),
#   ('go', 'go', 'ROOT'),
#   ('as', 'go', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('simple', 'sailor', 'amod'),
#   ('sailor', 'as', 'pobj'),
#   (',', 'go', 'punct'),
#   ('right', 'before', 'advmod'),
#   ('before', 'plumb', 'prep'),
#   ('the', 'mast', 'det'),
#   ('mast', 'before', 'pobj'),
#   (',', 'plumb', 'punct'),
#   ('plumb', 'go', 'advcl'),
#   ('down', 'plumb', 'prt'),
#   ('into', 'plumb', 'prep'),
#   ('the', 'forecastle', 'det'),
#   ('forecastle', 'into', 'pobj'),
#   (',', 'plumb', 'punct'),
#   ('aloft', 'there', 'advmod'),
#   ('there', 'plumb', 'advmod'),
#   ('to', 'there', 'prep'),
#   ('the', 'head', 'det'),
#   ('royal', 'head', 'amod'),
#   ('mast', 'head', 'compound'),
#   ('-', 'head', 'punct'),
#   ('head', 'to', 'pobj'),
#   ('.', 'go', 'punct')],
#  [('True', 'order', 'advmod'),
#   (',', 'order', 'punct'),
#   ('they', 'order', 'nsubj'),
#   ('rather', 'order', 'advmod'),
#   ('order', 'order', 'ROOT'),
#   ('me', 'order', 'dobj'),
#   ('about', 'order', 'prep'),
#   ('some', 'about', 'pobj'),
#   (',', 'order', 'punct'),
#   ('and', 'order', 'cc'),
#   ('make', 'order', 'conj'),
#   ('me', 'jump', 'nsubj'),
#   ('jump', 'make', 'ccomp'),
#   ('from', 'jump', 'prep'),
#   ('spar', 'from', 'pobj'),
#   ('to', 'jump', 'prep'),
#   ('spar', 'to', 'pobj'),
#   (',', 'jump', 'punct'),
#   ('like', 'jump', 'prep'),
#   ('a', 'grasshopper', 'det'),
#   ('grasshopper', 'like', 'pobj'),
#   ('in', 'grasshopper', 'prep'),
#   ('a', 'meadow', 'det'),
#   ('May', 'meadow', 'compound'),
#   ('meadow', 'in', 'pobj'),
#   ('.', 'order', 'punct')],
#  [('And', 'is', 'cc'),
#   ('at', 'is', 'prep'),
#   ('first', 'at', 'pcomp'),
#   (',', 'is', 'punct'),
#   ('this', 'sort', 'det'),
#   ('sort', 'is', 'nsubj'),
#   ('of', 'sort', 'prep'),
#   ('thing', 'of', 'pobj'),
#   ('is', 'is', 'ROOT'),
#   ('unpleasant', 'is', 'acomp'),
#   ('enough', 'unpleasant', 'advmod'),
#   ('.', 'is', 'punct')],
#  [('It', 'touches', 'nsubj'),
#   ('touches', 'touches', 'ROOT'),
#   ('one', 's', 'nsubj'),
#   ("'", 's', 'punct'),
#   ('s', 'sense', 'nummod'),
#   ('sense', 'touches', 'dobj'),
#   ('of', 'sense', 'prep'),
#   ('honour', 'of', 'pobj'),
#   (',', 'touches', 'punct'),
#   ('particularly', 'come', 'advmod'),
#   ('if', 'come', 'mark'),
#   ('you', 'come', 'nsubj'),
#   ('come', 'touches', 'advcl'),
#   ('of', 'come', 'prep'),
#   ('an', 'family', 'det'),
#   ('old', 'family', 'amod'),
#   ('established', 'family', 'amod'),
#   ('family', 'of', 'pobj'),
#   ('in', 'family', 'prep'),
#   ('the', 'land', 'det'),
#   ('land', 'in', 'pobj'),
#   (',', 'family', 'punct'),
#   ('the', 'Rensselaers', 'det'),
#   ('Van', 'Rensselaers', 'compound'),
#   ('Rensselaers', 'family', 'appos'),
#   (',', 'Rensselaers', 'punct'),
#   ('or', 'Rensselaers', 'cc'),
#   ('Randolphs', 'Rensselaers', 'conj'),
#   (',', 'Randolphs', 'punct'),
#   ('or', 'Randolphs', 'cc'),
#   ('Hardicanutes', 'Randolphs', 'conj'),
#   ('.', 'touches', 'punct')],
#  [('And', 'lording', 'cc'),
#   ('more', 'lording', 'advmod'),
#   ('than', 'more', 'prep'),
#   ('all', 'than', 'pobj'),
#   (',', 'lording', 'punct'),
#   ('if', 'previous', 'mark'),
#   ('just', 'previous', 'advmod'),
#   ('previous', 'lording', 'advcl'),
#   ('to', 'previous', 'prep'),
#   ('putting', 'to', 'pcomp'),
#   ('your', 'hand', 'poss'),
#   ('hand', 'putting', 'dobj'),
#   ('into', 'putting', 'prep'),
#   ('the', 'pot', 'det'),
#   ('tar', 'pot', 'compound'),
#   ('-', 'pot', 'punct'),
#   ('pot', 'into', 'pobj'),
#   (',', 'lording', 'punct'),
#   ('you', 'lording', 'nsubj'),
#   ('have', 'lording', 'aux'),
#   ('been', 'lording', 'aux'),
#   ('lording', 'lording', 'ROOT'),
#   ('it', 'lording', 'dobj'),
#   ('as', 'lording', 'prep'),
#   ('a', 'schoolmaster', 'det'),
#   ('country', 'schoolmaster', 'compound'),
#   ('schoolmaster', 'as', 'pobj'),
#   (',', 'lording', 'punct'),
#   ('making', 'lording', 'advcl'),
#   ('the', 'boys', 'det'),
#   ('tallest', 'boys', 'amod'),
#   ('boys', 'stand', 'nsubj'),
#   ('stand', 'making', 'ccomp'),
#   ('in', 'stand', 'prep'),
#   ('awe', 'in', 'pobj'),
#   ('of', 'awe', 'prep'),
#   ('you', 'of', 'pobj'),
#   ('.', 'lording', 'punct')],
#  [('The', 'transition', 'det'),
#   ('transition', 'is', 'nsubj'),
#   ('is', 'assure', 'ccomp'),
#   ('a', 'one', 'det'),
#   ('keen', 'one', 'amod'),
#   ('one', 'is', 'attr'),
#   (',', 'assure', 'punct'),
#   ('I', 'assure', 'nsubj'),
#   ('assure', 'assure', 'ROOT'),
#   ('you', 'assure', 'dobj'),
#   (',', 'assure', 'punct'),
#   ('from', 'assure', 'prep'),
#   ('a', 'schoolmaster', 'det'),
#   ('schoolmaster', 'from', 'pobj'),
#   ('to', 'from', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('sailor', 'to', 'pobj'),
#   (',', 'assure', 'punct'),
#   ('and', 'assure', 'cc'),
#   ('requires', 'assure', 'conj'),
#   ('a', 'decoction', 'det'),
#   ('strong', 'decoction', 'amod'),
#   ('decoction', 'requires', 'dobj'),
#   ('of', 'decoction', 'prep'),
#   ('Seneca', 'of', 'pobj'),
#   ('and', 'Seneca', 'cc'),
#   ('the', 'Stoics', 'det'),
#   ('Stoics', 'Seneca', 'conj'),
#   ('to', 'enable', 'aux'),
#   ('enable', 'requires', 'advcl'),
#   ('you', 'enable', 'dobj'),
#   ('to', 'enable', 'prep'),
#   ('grin', 'to', 'pobj'),
#   ('and', 'enable', 'cc'),
#   ('bear', 'enable', 'conj'),
#   ('it', 'bear', 'dobj'),
#   ('.', 'assure', 'punct')],
#  [('But', 'wears', 'cc'),
#   ('even', 'wears', 'advmod'),
#   ('this', 'wears', 'nsubj'),
#   ('wears', 'wears', 'ROOT'),
#   ('off', 'wears', 'prt'),
#   ('in', 'wears', 'prep'),
#   ('time', 'in', 'pobj'),
#   ('.', 'wears', 'punct')],
#  [('What', 'What', 'ROOT'),
#   ('of', 'What', 'prep'),
#   ('it', 'of', 'pobj'),
#   (',', 'What', 'punct'),
#   ('if', 'get', 'mark'),
#   ('some', 'hunks', 'det'),
#   ('old', 'hunks', 'amod'),
# ...
#   ('considering', 'is', 'advcl'),
#   ('that', 'believe', 'mark'),
#   ('we', 'believe', 'nsubj'),
#   ('so', 'earnestly', 'advmod'),
#   ('earnestly', 'believe', 'advmod'),
#   ('believe', 'considering', 'ccomp'),
#   ('money', 'believe', 'dobj'),
#   ('to', 'be', 'aux'),
#   ('be', 'money', 'relcl'),
#   ('the', 'root', 'det'),
#   ('root', 'be', 'attr'),
#   ('of', 'root', 'prep'),
#   ('all', 'ills', 'det'),
#   ('earthly', 'ills', 'amod'),
#   ('ills', 'of', 'pobj'),
#   (',', 'believe', 'punct'),
#   ('and', 'believe', 'cc'),
#   ('that', 'enter', 'mark'),
#   ('on', 'enter', 'prep'),
#   ('no', 'account', 'det'),
#   ('account', 'on', 'pobj'),
#   ('can', 'enter', 'aux'),
#   ('a', 'man', 'det'),
#   ('monied', 'man', 'amod'),
#   ('man', 'enter', 'nsubj'),
#   ('enter', 'believe', 'conj'),
#   ('heaven', 'enter', 'dobj'),
#   ('.', 'is', 'punct')],
#  [('Ah', 'Ah', 'ROOT'), ('!', 'Ah', 'punct')],
#  [('how', 'cheerfully', 'advmod'),
#   ('cheerfully', 'consign', 'advmod'),
#   ('we', 'consign', 'nsubj'),
#   ('consign', 'consign', 'ROOT'),
#   ('ourselves', 'consign', 'dobj'),
#   ('to', 'consign', 'prep'),
#   ('perdition', 'to', 'pobj'),
#   ('!', 'consign', 'punct')],
#  [('Finally', 'go', 'advmod'),
#   (',', 'go', 'punct'),
#   ('I', 'go', 'nsubj'),
#   ('always', 'go', 'advmod'),
#   ('go', 'go', 'ROOT'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'go', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('sailor', 'as', 'pobj'),
#   (',', 'go', 'punct'),
#   ('because', 'go', 'prep'),
#   ('of', 'because', 'pcomp'),
#   ('the', 'exercise', 'det'),
#   ('wholesome', 'exercise', 'amod'),
#   ('exercise', 'because', 'pobj'),
#   ('and', 'exercise', 'cc'),
#   ('pure', 'air', 'amod'),
#   ('air', 'exercise', 'conj'),
#   ('of', 'exercise', 'prep'),
#   ('the', 'deck', 'det'),
#   ('fore', 'castle', 'amod'),
#   ('-', 'castle', 'punct'),
#   ('castle', 'deck', 'compound'),
#   ('deck', 'of', 'pobj'),
#   ('.', 'go', 'punct')],
#  [('For', 'are', 'prep'),
#   ('as', 'For', 'pcomp'),
#   ('in', 'as', 'prep'),
#   ('this', 'world', 'det'),
#   ('world', 'in', 'pobj'),
#   (',', 'are', 'punct'),
#   ('head', 'winds', 'compound'),
#   ('winds', 'are', 'nsubj'),
#   ('are', 'are', 'ROOT'),
#   ('far', 'more', 'advmod'),
#   ('more', 'prevalent', 'advmod'),
#   ('prevalent', 'are', 'acomp'),
#   ('than', 'prevalent', 'prep'),
#   ('winds', 'than', 'pobj'),
#   ('from', 'winds', 'prep'),
#   ('astern', 'from', 'pobj'),
#   ('(', 'gets', 'punct'),
#   ('that', 'is', 'advmod'),
#   ('is', 'gets', 'advmod'),
#   (',', 'is', 'punct'),
#   ('if', 'violate', 'mark'),
#   ('you', 'violate', 'nsubj'),
#   ('never', 'violate', 'neg'),
#   ('violate', ',', 'intj'),
#   ('the', 'maxim', 'det'),
#   ('Pythagorean', 'maxim', 'amod'),
#   ('maxim', 'violate', 'dobj'),
#   (')', 'violate', 'punct'),
#   (',', 'gets', 'punct'),
#   ('so', 'gets', 'advmod'),
#   ('for', 'gets', 'prep'),
#   ('the', 'part', 'det'),
#   ('most', 'part', 'amod'),
#   ('part', 'for', 'pobj'),
#   ('the', 'Commodore', 'det'),
#   ('Commodore', 'gets', 'nsubj'),
#   ('on', 'Commodore', 'prep'),
#   ('the', 'deck', 'det'),
#   ('quarter', 'deck', 'compound'),
#   ('-', 'deck', 'punct'),
#   ('deck', 'on', 'pobj'),
#   ('gets', 'are', 'parataxis'),
#   ('his', 'atmosphere', 'poss'),
#   ('atmosphere', 'gets', 'dobj'),
#   ('at', 'gets', 'prep'),
#   ('second', 'hand', 'amod'),
#   ('hand', 'at', 'pobj'),
#   ('from', 'gets', 'prep'),
#   ('the', 'sailors', 'det'),
#   ('sailors', 'from', 'pobj'),
#   ('on', 'sailors', 'prep'),
#   ('the', 'forecastle', 'det'),
#   ('forecastle', 'on', 'pobj'),
#   ('.', 'are', 'punct')],
#  [('He', 'thinks', 'nsubj'),
#   ('thinks', 'thinks', 'ROOT'),
#   ('he', 'breathes', 'nsubj'),
#   ('breathes', 'thinks', 'ccomp'),
#   ('it', 'breathes', 'dobj'),
#   ('first', 'breathes', 'advmod'),
#   (';', 'thinks', 'punct'),
#   ('but', 'so', 'cc'),
#   ('not', 'so', 'neg'),
#   ('so', 'thinks', 'conj'),
#   ('.', 'thinks', 'punct')],
#  [('In', 'lead', 'prep'),
#   ('much', 'way', 'advmod'),
#   ('the', 'way', 'det'),
#   ('same', 'way', 'amod'),
#   ('way', 'In', 'pobj'),
#   ('do', 'lead', 'aux'),
#   ('the', 'commonalty', 'det'),
#   ('commonalty', 'lead', 'nsubj'),
#   ('lead', 'lead', 'ROOT'),
#   ('their', 'leaders', 'poss'),
#   ('leaders', 'lead', 'dobj'),
#   ('in', 'lead', 'prep'),
#   ('many', 'things', 'amod'),
#   ('other', 'things', 'amod'),
#   ('things', 'in', 'pobj'),
#   (',', 'lead', 'punct'),
#   ('at', 'lead', 'prep'),
#   ('the', 'time', 'det'),
#   ('same', 'time', 'amod'),
#   ('time', 'at', 'pobj'),
#   ('that', 'suspect', 'advmod'),
#   ('the', 'leaders', 'det'),
#   ('leaders', 'suspect', 'nsubj'),
#   ('little', 'suspect', 'npadvmod'),
#   ('suspect', 'time', 'relcl'),
#   ('it', 'suspect', 'dobj'),
#   ('.', 'lead', 'punct')],
#  [('But', 'was', 'cc'),
#   ('wherefore', 'was', 'intj'),
#   ('it', 'was', 'nsubj'),
#   ('was', 'answer', 'ccomp'),
#   ('that', 'take', 'mark'),
#   ('after', 'take', 'prep'),
#   ('having', 'smelt', 'aux'),
#   ('repeatedly', 'smelt', 'advmod'),
#   ('smelt', 'after', 'pcomp'),
#   ('the', 'sea', 'det'),
#   ('sea', 'smelt', 'dobj'),
#   ('as', 'smelt', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('merchant', 'sailor', 'compound'),
#   ('sailor', 'as', 'pobj'),
#   (',', 'take', 'punct'),
#   ('I', 'take', 'nsubj'),
#   ('should', 'take', 'aux'),
#   ('now', 'take', 'advmod'),
#   ('take', 'was', 'ccomp'),
#   ('it', 'take', 'dobj'),
#   ('into', 'take', 'prep'),
#   ('my', 'head', 'poss'),
#   ('head', 'into', 'pobj'),
#   ('to', 'go', 'aux'),
#   ('go', 'take', 'advcl'),
#   ('on', 'go', 'prep'),
#   ('a', 'voyage', 'det'),
#   ('whaling', 'voyage', 'amod'),
#   ('voyage', 'on', 'pobj'),
#   (';', 'answer', 'punct'),
#   ('this', 'officer', 'det'),
#   ('the', 'officer', 'det'),
#   ('invisible', 'officer', 'amod'),
#   ('police', 'officer', 'compound'),
#   ('officer', 'answer', 'dep'),
#   ('of', 'officer', 'prep'),
#   ('the', 'Fates', 'det'),
#   ('Fates', 'of', 'pobj'),
#   (',', 'officer', 'punct'),
#   ('who', 'has', 'nsubj'),
#   ('has', 'officer', 'relcl'),
#   ('the', 'surveillance', 'det'),
#   ('constant', 'surveillance', 'amod'),
#   ('surveillance', 'has', 'dobj'),
#   ('of', 'surveillance', 'prep'),
#   ('me', 'of', 'pobj'),
#   (',', 'has', 'punct'),
#   ('and', 'has', 'cc'),
#   ('secretly', 'dogs', 'advmod'),
#   ('dogs', 'has', 'conj'),
#   ('me', 'dogs', 'dobj'),
#   (',', 'dogs', 'punct'),
#   ('and', 'dogs', 'cc'),
#   ('influences', 'dogs', 'conj'),
#   ('me', 'influences', 'dobj'),
#   ('in', 'influences', 'prep'),
#   ('some', 'way', 'det'),
#   ('unaccountable', 'way', 'amod'),
#   ('way', 'in', 'pobj'),
#   ('--', 'answer', 'punct'),
#   ('he', 'answer', 'nsubj'),
#   ('can', 'answer', 'aux'),
#   ('better', 'answer', 'advmod'),
#   ('answer', 'answer', 'ROOT'),
#   ('than', 'answer', 'prep'),
#   ('any', 'one', 'det'),
#   ('one', 'than', 'pobj'),
#   ('else', 'one', 'advmod'),
#   ('.', 'answer', 'punct')],
#  [('And', 'And', 'ROOT'),
#   (',', 'And', 'punct'),
#   ('doubtless', ',', 'intj'),
#   (',', 'going', 'punct'),
#   ('my', 'going', 'nsubj'),
#   ('going', ',', 'intj'),
#   ('on', 'going', 'prep'),
#   ('this', 'voyage', 'det'),
#   ('whaling', 'voyage', 'amod'),
#   ('voyage', 'on', 'pobj'),
#   (',', 'going', 'punct'),
#   ('formed', 'going', 'dep'),
#   ('part', 'formed', 'dobj'),
#   ('of', 'part', 'prep'),
#   ('the', 'programme', 'det'),
#   ('grand', 'programme', 'amod'),
#   ('programme', 'of', 'pobj'),
#   ('of', 'programme', 'prep'),
#   ('Providence', 'of', 'pobj'),
#   ('that', 'drawn', 'nsubjpass'),
#   ('was', 'drawn', 'auxpass'),
#   ('drawn', 'programme', 'relcl'),
#   ('up', 'drawn', 'prt'),
#   ('a', 'time', 'det'),
#   ('long', 'time', 'amod'),
#   ('time', 'ago', 'npadvmod'),
#   ('ago', 'drawn', 'advmod'),
#   ('.', 'going', 'punct')],
#  [('It', 'came', 'nsubj'),
#   ('came', 'came', 'ROOT'),
#   ('in', 'came', 'prt'),
#   ('as', 'came', 'prep'),
#   ('a', 'sort', 'det'),
#   ('sort', 'as', 'pobj'),
#   ('of', 'sort', 'prep'),
#   ('brief', 'interlude', 'amod'),
#   ('interlude', 'of', 'pobj'),
#   ('and', 'interlude', 'cc'),
#   ('solo', 'interlude', 'conj'),
#   ('between', 'sort', 'prep'),
#   ('more', 'extensive', 'advmod'),
#   ('extensive', 'performances', 'amod'),
#   ('performances', 'between', 'pobj'),
#   ('.', 'came', 'punct')],
#  [('I', 'take', 'nsubj'),
#   ('take', 'take', 'ROOT'),
#   ('it', 'take', 'dobj'),
#   ('that', 'run', 'mark'),
#   ('this', 'part', 'det'),
#   ('part', 'run', 'nsubj'),
#   ('of', 'part', 'prep'),
#   ('the', 'bill', 'det'),
#   ('bill', 'of', 'pobj'),
#   ('must', 'run', 'aux'),
#   ('have', 'run', 'aux'),
#   ('run', 'take', 'ccomp'),
#   ('something', 'run', 'dobj'),
#   ('like', 'something', 'prep'),
#   ('this', 'like', 'pobj'),
#   (':', 'take', 'punct')],
#  [('"', 'CONTESTED', 'punct'),
#   ('GRAND', 'CONTESTED', 'nsubj'),
#   ('CONTESTED', 'CONTESTED', 'ROOT'),
#   ('ELECTION', 'CONTESTED', 'dobj'),
#   ('FOR', 'ELECTION', 'prep'),
#   ('THE', 'PRESIDENCY', 'det'),
#   ('PRESIDENCY', 'FOR', 'pobj'),
#   ('OF', 'PRESIDENCY', 'prep'),
#   ('THE', 'STATES', 'det'),
#   ('UNITED', 'STATES', 'compound'),
#   ('STATES', 'OF', 'pobj'),
#   ('.', 'CONTESTED', 'punct')],
#  [('"', 'VOYAGE', 'punct'),
#   ('WHALING', 'VOYAGE', 'compound'),
#   ('VOYAGE', 'VOYAGE', 'ROOT'),
#   ('BY', 'VOYAGE', 'prep'),
#   ('ONE', 'ISHMAEL', 'compound'),
#   ('ISHMAEL', 'BY', 'pobj'),
#   ('.', 'VOYAGE', 'punct')],
#  [('"', 'BATTLE', 'punct'),
#   ('BLOODY', 'BATTLE', 'amod'),
#   ('BATTLE', 'BATTLE', 'ROOT'),
#   ('IN', 'BATTLE', 'prep'),
#   ('AFFGHANISTAN', 'IN', 'pobj'),
#   ('.', 'BATTLE', 'punct'),
#   ('"', 'BATTLE', 'punct')],
#  [('Though', 'tell', 'mark'),
#   ('I', 'tell', 'nsubj'),
#   ('can', 'tell', 'aux'),
#   ('not', 'tell', 'neg'),
#   ('tell', 'think', 'advcl'),
#   ('why', 'was', 'advmod'),
#   ('it', 'was', 'nsubj'),
#   ('was', 'tell', 'ccomp'),
#   ('exactly', 'was', 'advmod'),
#   ('that', 'put', 'mark'),
#   ('those', 'managers', 'det'),
#   ('stage', 'managers', 'compound'),
#   ('managers', 'put', 'nsubj'),
#   (',', 'managers', 'punct'),
#   ('the', 'Fates', 'det'),
#   ('Fates', 'managers', 'appos'),
#   (',', 'put', 'punct'),
#   ('put', 'was', 'ccomp'),
#   ('me', 'put', 'dobj'),
#   ('down', 'put', 'prt'),
#   ('for', 'put', 'prep'),
#   ('this', 'part', 'det'),
#   ('shabby', 'part', 'amod'),
#   ('part', 'for', 'pobj'),
#   ('of', 'part', 'prep'),
#   ('a', 'voyage', 'det'),
#   ('whaling', 'voyage', 'amod'),
#   ('voyage', 'of', 'pobj'),
#   (',', 'put', 'punct'),
#   ('when', 'set', 'advmod'),
#   ('others', 'set', 'nsubjpass'),
#   ('were', 'set', 'auxpass'),
#   ('set', 'put', 'advcl'),
#   ('down', 'set', 'prt'),
#   ('for', 'set', 'prep'),
#   ('magnificent', 'parts', 'amod'),
#   ('parts', 'for', 'pobj'),
#   ('in', 'parts', 'prep'),
#   ('high', 'tragedies', 'amod'),
#   ('tragedies', 'in', 'pobj'),
#   (',', 'set', 'punct'),
#   ('and', 'set', 'cc'),
#   ('short', 'parts', 'amod'),
#   ('and', 'short', 'cc'),
#   ('easy', 'short', 'conj'),
#   ('parts', 'set', 'conj'),
#   ('in', 'parts', 'prep'),
#   ('genteel', 'comedies', 'amod'),
#   ('comedies', 'in', 'pobj'),
#   (',', 'parts', 'punct'),
#   ('and', 'parts', 'cc'),
#   ('jolly', 'parts', 'amod'),
#   ('parts', 'parts', 'conj'),
#   ('in', 'parts', 'prep'),
#   ('farces', 'in', 'pobj'),
#   ('--', 'put', 'punct'),
#   ('though', 'tell', 'mark'),
#   ('I', 'tell', 'nsubj'),
#   ('can', 'tell', 'aux'),
#   ('not', 'tell', 'neg'),
#   ('tell', 'put', 'advcl'),
#   ('why', 'was', 'advmod'),
#   ('this', 'was', 'nsubj'),
#   ('was', 'tell', 'ccomp'),
#   ('exactly', 'was', 'advmod'),
#   (';', 'tell', 'punct'),
#   ('yet', 'tell', 'cc'),
#   (',', 'tell', 'punct'),
#   ('now', 'recall', 'advmod'),
#   ('that', 'recall', 'mark'),
#   ('I', 'recall', 'nsubj'),
#   ('recall', 'tell', 'ccomp'),
#   ('all', 'circumstances', 'predet'),
#   ('the', 'circumstances', 'det'),
#   ('circumstances', 'recall', 'dobj'),
#   (',', 'think', 'punct'),
#   ('I', 'think', 'nsubj'),
#   ('think', 'think', 'ROOT'),
#   ('I', 'see', 'nsubj'),
#   ('can', 'see', 'aux'),
#   ('see', 'think', 'ccomp'),
#   ('a', 'little', 'det'),
#   ('little', 'see', 'dobj'),
#   ('into', 'see', 'prep'),
#   ('the', 'springs', 'det'),
#   ('springs', 'into', 'pobj'),
#   ('and', 'springs', 'cc'),
#   ('motives', 'springs', 'conj'),
#   ('which', 'presented', 'nsubjpass'),
#   ('being', 'presented', 'auxpass'),
#   ('cunningly', 'presented', 'advmod'),
#   ('presented', 'springs', 'relcl'),
#   ('to', 'presented', 'prep'),
#   ('me', 'to', 'pobj'),
#   ('under', 'presented', 'prep'),
#   ('various', 'disguises', 'amod'),
#   ('disguises', 'under', 'pobj'),
#   (',', 'see', 'punct'),
#   ('induced', 'think', 'conj'),
#   ('me', 'induced', 'dobj'),
#   ('to', 'set', 'aux'),
#   ('set', 'induced', 'xcomp'),
#   ('about', 'set', 'prep'),
#   ('performing', 'about', 'pcomp'),
#   ('the', 'part', 'det'),
#   ('part', 'performing', 'dobj'),
#   ('I', 'did', 'nsubj'),
#   ('did', 'part', 'relcl'),
#   (',', 'induced', 'punct'),
#   ('besides', 'induced', 'prep'),
#   ('cajoling', 'besides', 'pcomp'),
#   ('me', 'cajoling', 'dobj'),
#   ('into', 'cajoling', 'prep'),
#   ('the', 'delusion', 'det'),
#   ('delusion', 'into', 'pobj'),
#   ('that', 'was', 'mark'),
#   ('it', 'was', 'nsubj'),
#   ('was', 'delusion', 'acl'),
#   ('a', 'choice', 'det'),
#   ('choice', 'was', 'attr'),
#   ('resulting', 'choice', 'acl'),
#   ('from', 'resulting', 'prep'),
#   ('my', 'freewill', 'poss'),
#   ('own', 'freewill', 'amod'),
#   ('unbiased', 'freewill', 'amod'),
#   ('freewill', 'from', 'pobj'),
#   ('and', 'resulting', 'cc'),
#   ('discriminating', 'resulting', 'conj'),
#   ('judgment', 'discriminating', 'dobj'),
#   ('.', 'think', 'punct')],
#  [('Chief', 'was', 'nsubj'),
#   ('among', 'Chief', 'prep'),
#   ('these', 'motives', 'det'),
#   ('motives', 'among', 'pobj'),
#   ('was', 'was', 'ROOT'),
#   ('the', 'idea', 'det'),
#   ('overwhelming', 'idea', 'amod'),
#   ('idea', 'was', 'attr'),
#   ('of', 'idea', 'prep'),
#   ('the', 'whale', 'det'),
#   ('great', 'whale', 'amod'),
#   ('whale', 'of', 'pobj'),
#   ('himself', 'whale', 'appos'),
#   ('.', 'was', 'punct')],
#  [('Such', 'monster', 'predet'),
#   ('a', 'monster', 'det'),
#   ('portentous', 'monster', 'amod'),
#   ('and', 'portentous', 'cc'),
#   ('mysterious', 'portentous', 'conj'),
#   ('monster', 'roused', 'nsubj'),
#   ('roused', 'roused', 'ROOT'),
#   ('all', 'curiosity', 'predet'),
#   ('my', 'curiosity', 'poss'),
#   ('curiosity', 'roused', 'dobj'),
#   ('.', 'roused', 'punct')],
#  [('Then', 'helped', 'advmod'),
#   ('the', 'seas', 'det'),
#   ('wild', 'seas', 'amod'),
#   ('and', 'wild', 'cc'),
#   ('distant', 'wild', 'conj'),
#   ('seas', 'helped', 'dep'),
#   ('where', 'rolled', 'advmod'),
#   ('he', 'rolled', 'nsubj'),
#   ('rolled', 'seas', 'relcl'),
#   ('his', 'bulk', 'poss'),
#   ('island', 'bulk', 'compound'),
#   ('bulk', 'rolled', 'dobj'),
#   (';', 'seas', 'punct'),
#   ('the', 'perils', 'det'),
#   ('undeliverable', 'perils', 'amod'),
#   (',', 'perils', 'punct'),
#   ('nameless', 'perils', 'compound'),
#   ('perils', 'seas', 'appos'),
#   ('of', 'perils', 'prep'),
#   ('the', 'whale', 'det'),
#   ('whale', 'of', 'pobj'),
#   (';', 'helped', 'punct'),
#   ('these', 'helped', 'nsubj'),
#   (',', 'helped', 'punct'),
#   ('with', 'helped', 'prep'),
#   ('all', 'marvels', 'predet'),
#   ('the', 'marvels', 'det'),
#   ('attending', 'marvels', 'amod'),
#   ('marvels', 'with', 'pobj'),
#   ('of', 'marvels', 'prep'),
#   ('a', 'thousand', 'quantmod'),
#   ('thousand', 'sights', 'nummod'),
#   ('Patagonian', 'sights', 'amod'),
#   ('sights', 'of', 'pobj'),
#   ('and', 'marvels', 'cc'),
#   ('sounds', 'marvels', 'conj'),
#   (',', 'helped', 'punct'),
#   ('helped', 'helped', 'ROOT'),
#   ('to', 'sway', 'aux'),
#   ('sway', 'helped', 'xcomp'),
#   ('me', 'sway', 'dobj'),
#   ('to', 'sway', 'prep'),
#   ('my', 'wish', 'poss'),
#   ('wish', 'to', 'pobj'),
#   ('.', 'helped', 'punct')],
#  [('With', 'been', 'prep'),
#   ('other', 'men', 'amod'),
#   ('men', 'With', 'pobj'),
#   (',', 'been', 'punct'),
#   ('perhaps', 'been', 'advmod'),
#   (',', 'been', 'punct'),
#   ('such', 'things', 'amod'),
#   ('things', 'been', 'nsubj'),
#   ('would', 'been', 'aux'),
#   ('not', 'been', 'neg'),
#   ('have', 'been', 'aux'),
#   ('been', 'been', 'ROOT'),
#   ('inducements', 'been', 'attr'),
#   (';', 'been', 'punct'),
#   ('but', 'been', 'cc'),
#   ('as', 'tormented', 'prep'),
#   ('for', 'as', 'prep'),
#   ('me', 'for', 'pobj'),
#   (',', 'tormented', 'punct'),
#   ('I', 'tormented', 'nsubjpass'),
#   ('am', 'tormented', 'auxpass'),
#   ('tormented', 'been', 'conj'),
#   ('with', 'tormented', 'prep'),
#   ('an', 'itch', 'det'),
#   ('everlasting', 'itch', 'amod'),
#   ('itch', 'with', 'pobj'),
#   ('for', 'itch', 'prep'),
#   ('things', 'for', 'pobj'),
#   ('remote', 'things', 'amod'),
#   ('.', 'tormented', 'punct')]]

# %% [markdown]
# Instead of doing this at a word-by-word basis, we can do it by larger chunks, the noun phrases.

# %%
[[(c.text, c.root.head.text, c.root.dep_) for c in nlp(sentence).noun_chunks] 
 for sentence in documents[:100]]
# Out:
# [[('Loomings', 'Loomings', 'ROOT')],
#  [('me', 'Call', 'dobj')],
#  [('little or no money', 'having', 'dobj'),
#   ('my purse', 'in', 'pobj'),
#   ('nothing', 'interest', 'nsubj'),
#   ('me', 'interest', 'dobj'),
#   ('shore', 'on', 'pobj'),
#   ('I', 'thought', 'nsubj'),
#   ('I', 'sail', 'nsubj'),
#   ('the watery part', 'see', 'dobj'),
#   ('the world', 'of', 'pobj')],
#  [('It', 'is', 'nsubj'),
#   ('a way', 'is', 'attr'),
#   ('I', 'have', 'nsubj'),
#   ('the spleen', 'driving', 'dobj'),
#   ('the circulation', 'regulating', 'dobj')],
#  [('I', 'find', 'nsubj'),
#   ('myself', 'growing', 'nsubj'),
#   ('the mouth', 'about', 'pobj'),
#   ('it', 'is', 'nsubj'),
#   ('my soul', 'in', 'pobj'),
#   ('I', 'find', 'nsubj'),
#   ('myself', 'pausing', 'nsubj'),
#   ('coffin warehouses', 'before', 'pobj'),
#   ('the rear', 'bringing', 'dobj'),
#   ('every funeral', 'of', 'pobj'),
#   ('I', 'meet', 'nsubj'),
#   ('my hypos', 'get', 'nsubj'),
#   ('such an upper hand', 'get', 'dobj'),
#   ('me', 'of', 'pobj'),
#   ('it', 'requires', 'nsubj'),
#   ('a strong moral principle', 'requires', 'dobj'),
#   ('me', 'prevent', 'dobj'),
#   ('the street', 'into', 'pobj'),
#   ("people ' s", 'knocking', 'dobj'),
#   ('hats', 'knocking', 'dobj'),
#   ('I', 'account', 'nsubj'),
#   ('it', 'account', 'dobj'),
#   ('sea', 'to', 'pobj'),
#   ('I', 'can', 'nsubj')],
#  [('my substitute', 'is', 'attr'),
#   ('pistol', 'for', 'pobj'),
#   ('ball', 'pistol', 'conj')],
#  [('Cato', 'throws', 'nsubj'),
#   ('himself', 'throws', 'dobj'),
#   ('his sword', 'upon', 'pobj'),
#   ('I', 'take', 'nsubj'),
#   ('the ship', 'to', 'pobj')],
#  [('nothing', 'is', 'attr')],
#  [('they', 'knew', 'nsubj'),
#   ('it', 'knew', 'dobj'),
#   ('almost all men', 'cherish', 'nsubj'),
#   ('their degree', 'in', 'pobj'),
#   ('some time', 'men', 'appos'),
#   ('the same feelings', 'cherish', 'dobj'),
#   ('the ocean', 'towards', 'pobj'),
#   ('me', 'with', 'pobj')],
#  [('your insular city', 'is', 'attr'),
#   ('the Manhattoes', 'of', 'pobj'),
#   ('wharves', 'by', 'pobj'),
#   ('Indian isles', 'as', 'pobj'),
#   ('coral reefs', 'by', 'pobj'),
#   ('commerce', 'surrounds', 'nsubj'),
#   ('it', 'surrounds', 'dobj'),
#   ('her surf', 'with', 'pobj')],
#  [('the streets', 'take', 'nsubj'), ('you', 'take', 'dobj')],
#  [('Its extreme downtown', 'is', 'nsubj'),
#   ('the battery', 'is', 'attr'),
#   ('that noble mole', 'washed', 'nsubjpass'),
#   ('waves', 'by', 'pobj'),
#   ('breezes', 'by', 'pobj'),
#   ('sight', 'of', 'pobj'),
#   ('land', 'of', 'pobj')],
#  [('the crowds', 'at', 'pobj'), ('water - gazers', 'of', 'pobj')],
#  [('the city', 'Circumambulate', 'dobj'),
#   ('a dreamy Sabbath afternoon', 'of', 'pobj')],
#  [('Corlears Hook', 'from', 'pobj'),
#   ('Coenties Slip', 'to', 'pobj'),
#   ('thence', 'from', 'pobj'),
#   ('Whitehall', 'by', 'pobj')],
#  [('What', 'see', 'dobj'),
#   ('you', 'see', 'nsubj'),
#   ('silent sentinels', 'like', 'pobj'),
#   ('the town', 'around', 'pobj'),
#   ('thousands', 'upon', 'pobj'),
#   ('mortal men', 'of', 'pobj'),
#   ('ocean reveries', 'in', 'pobj')],
#  [('the spiles', 'against', 'pobj'),
#   ('the pier - heads', 'upon', 'pobj'),
#   ('the bulwarks', 'over', 'pobj'),
#   ('ships', 'of', 'pobj'),
#   ('China', 'from', 'pobj'),
#   ('the rigging', 'in', 'pobj'),
#   ('a still better seaward peep', 'get', 'dobj')],
#  [('landsmen', 'are', 'attr'),
#   ('lath', 'in', 'pobj'),
#   ('plaster', 'lath', 'conj'),
#   ('counters', 'to', 'pobj'),
#   ('benches', 'to', 'pobj'),
#   ('desks', 'to', 'pobj')],
#  [],
#  [('the green fields', 'gone', 'nsubj')],
#  [('What', 'do', 'nsubj'), ('they', 'do', 'nsubj')],
#  [],
#  [('more crowds', 'come', 'nsubj'),
#   ('the water', 'for', 'pobj'),
#   ('a dive', 'for', 'pobj')],
#  [],
#  [('Nothing', 'content', 'nsubj'),
#   ('them', 'content', 'dobj'),
#   ('the land', 'of', 'pobj'),
#   ('loitering', 'suffice', 'nsubj'),
#   ('the shady lee', 'under', 'pobj'),
#   ('yonder warehouses', 'of', 'pobj')],
#  [],
#  [('They', 'get', 'nsubj'),
#   ('the water', 'nigh', 'appos'),
#   ('they', 'can', 'nsubj')],
#  [('they', 'stand', 'nsubj'),
#   ('them', 'of', 'pobj'),
#   ('leagues', 'miles', 'appos')],
#  [('they', 'come', 'nsubj'),
#   ('lanes', 'from', 'pobj'),
#   ('alleys', 'lanes', 'conj'),
#   ('streets', 'lanes', 'conj'),
#   ('avenues', 'streets', 'conj'),
#   ('north', 'lanes', 'appos'),
#   ('east', 'north', 'conj'),
#   ('south', 'east', 'conj'),
#   ('west', 'south', 'conj')],
#  [('they', 'unite', 'nsubj')],
#  [('me', 'Tell', 'dobj'),
#   ('the magnetic virtue', 'attract', 'nsubj'),
#   ('the needles', 'of', 'pobj'),
#   ('the compasses', 'of', 'pobj'),
#   ('all those ships', 'of', 'pobj'),
#   ('them', 'attract', 'dobj')],
#  [],
#  [('you', 'are', 'nsubj'),
#   ('the country', 'in', 'pobj'),
#   ('some high land', 'in', 'pobj'),
#   ('lakes', 'of', 'pobj')],
#  [('almost any path', 'Take', 'dobj'),
#   ('you', 'please', 'nsubj'),
#   ('it', 'carries', 'nsubj'),
#   ('you', 'carries', 'dobj'),
#   ('a dale', 'in', 'pobj'),
#   ('you', 'leaves', 'dobj'),
#   ('a pool', 'by', 'pobj'),
#   ('the stream', 'in', 'pobj')],
#  [('magic', 'is', 'attr'), ('it', 'in', 'pobj')],
#  [('men', 'of', 'pobj'),
#   ('his deepest reveries', 'in', 'pobj'),
#   ('that man', 'stand', 'dobj'),
#   ('his legs', 'on', 'pobj'),
#   ('his feet', 'set', 'dobj'),
#   ('he', 'lead', 'nsubj'),
#   ('you', 'lead', 'dobj'),
#   ('water', 'to', 'pobj'),
#   ('water', 'be', 'nsubj'),
#   ('all that region', 'in', 'pobj')],
#  [('you', 'be', 'nsubj'),
#   ('the great American desert', 'in', 'pobj'),
#   ('this experiment', 'try', 'dobj'),
#   ('your caravan', 'happen', 'nsubj'),
#   ('a metaphysical professor', 'with', 'pobj')],
#  [('meditation', 'wedded', 'nsubjpass'), ('water', 'meditation', 'conj')],
#  [('an artist', 'is', 'attr')],
#  [('He', 'desires', 'nsubj'),
#   ('you', 'paint', 'dative'),
#   ('most enchanting bit', 'quietest', 'appos'),
#   ('romantic landscape', 'of', 'pobj'),
#   ('all the valley', 'in', 'pobj'),
#   ('the Saco', 'of', 'pobj')],
#  [('What', 'is', 'attr'),
#   ('the chief element', 'is', 'nsubj'),
#   ('he', 'employs', 'nsubj')],
#  [('his trees', 'stand', 'dobj'),
#   ('a hollow trunk', 'with', 'pobj'),
#   ('a hermit', 'were', 'nsubj'),
#   ('a crucifix', 'hermit', 'conj'),
#   ('his meadow', 'sleeps', 'dobj'),
#   ('his cattle', 'sleep', 'dobj'),
#   ('yonder cottage', 'from', 'pobj'),
#   ('a sleepy smoke', 'goes', 'dobj')],
#  [('distant woodlands', 'into', 'pobj'),
#   ('a mazy way', 'winds', 'dobj'),
#   ('overlapping spurs', 'to', 'pobj'),
#   ('mountains', 'of', 'pobj'),
#   ('their hill - side blue', 'in', 'pobj')],
#  [('the picture', 'lies', 'nsubj'),
#   ('this pine - tree', 'shakes', 'nsubj'),
#   ('its sighs', 'shakes', 'dobj'),
#   ('leaves', 'like', 'pobj'),
#   ("this shepherd ' s head", 'upon', 'pobj'),
#   ("the shepherd ' s eye", 'fixed', 'nsubjpass'),
#   ('the magic stream', 'upon', 'pobj'),
#   ('him', 'before', 'pobj')],
#  [('the Prairies', 'visit', 'dobj'),
#   ('June', 'in', 'pobj'),
#   ('scores', 'for', 'pobj'),
#   ('scores', 'on', 'pobj'),
#   ('miles', 'of', 'pobj'),
#   ('you', 'wade', 'nsubj'),
#   ('Tiger - lilies', 'among', 'pobj'),
#   ('what', 'is', 'attr'),
#   ('the one charm', 'wanting', 'nsubj'),
#   ('a drop', 'is', 'attr'),
#   ('water', 'of', 'pobj')],
#  [('Niagara', 'Were', 'nsubj'),
#   ('a cataract', 'Niagara', 'conj'),
#   ('sand', 'of', 'pobj'),
#   ('you', 'travel', 'nsubj'),
#   ('your thousand miles', 'travel', 'dobj'),
#   ('it', 'see', 'dobj')],
#  [('the poor poet', 'deliberate', 'nsubj'),
#   ('Tennessee', 'of', 'pobj'),
#   ('two handfuls', 'receiving', 'dobj'),
#   ('silver', 'of', 'pobj'),
#   ('him', 'buy', 'dative'),
#   ('a coat', 'buy', 'dobj'),
#   ('he', 'needed', 'nsubj'),
#   ('his money', 'invest', 'dobj'),
#   ('a pedestrian trip', 'in', 'pobj'),
#   ('Rockaway Beach', 'to', 'pobj')],
#  [('almost every robust healthy boy', 'is', 'nsubj'),
#   ('a robust healthy soul', 'with', 'pobj'),
#   ('him', 'in', 'pobj'),
#   ('some time', 'at', 'pobj'),
#   ('sea', 'to', 'pobj')],
#  [('your first voyage', 'upon', 'pobj'),
#   ('a passenger', 'as', 'pobj'),
#   ('you', 'feel', 'nsubj'),
#   ('yourself', 'you', 'appos'),
#   ('such a mystical vibration', 'feel', 'dobj'),
#   ('you', 'were', 'nsubj'),
#   ('your ship', 'you', 'conj'),
#   ('sight', 'of', 'pobj'),
#   ('land', 'of', 'pobj')],
#  [('the old Persians', 'hold', 'nsubj'), ('the sea', 'holy', 'nsubj')],
#  [('the Greeks', 'give', 'nsubj'),
#   ('it', 'give', 'dative'),
#   ('a separate deity', 'give', 'dobj'),
#   ('own brother', 'give', 'conj'),
#   ('Jove', 'of', 'pobj')],
#  [('meaning', 'without', 'pobj')],
#  [('the meaning', 'deeper', 'dobj'),
#   ('that story', 'of', 'pobj'),
#   ('Narcissus', 'of', 'pobj'),
#   ('who', 'plunged', 'nsubj'),
#   ('he', 'grasp', 'nsubj'),
#   ('the tormenting', 'grasp', 'dobj'),
#   ('mild image', 'plunged', 'nsubj'),
#   ('he', 'saw', 'nsubj'),
#   ('the fountain', 'in', 'pobj'),
#   ('it', 'into', 'pobj')],
#  [('we', 'see', 'nsubj'),
#   ('ourselves', 'we', 'appos'),
#   ('all rivers', 'in', 'pobj'),
#   ('oceans', 'rivers', 'conj')],
#  [('It', 'is', 'nsubj'),
#   ('the image', 'is', 'attr'),
#   ('the ungraspable phantom', 'of', 'pobj'),
#   ('life', 'of', 'pobj'),
#   ('the key', 'is', 'attr'),
#   ('it', 'to', 'pobj')],
#  [('I', 'say', 'nsubj'),
#   ('I', 'am', 'nsubj'),
#   ('the habit', 'in', 'pobj'),
#   ('sea', 'to', 'pobj'),
#   ('I', 'begin', 'nsubj'),
#   ('hazy', 'grow', 'dobj'),
#   ('the eyes', 'about', 'pobj'),
#   ('my lungs', 'of', 'pobj'),
#   ('I', 'mean', 'nsubj'),
#   ('it', 'inferred', 'nsubj'),
#   ('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a passenger', 'as', 'pobj')],
#  [('a passenger', 'as', 'pobj'),
#   ('you', 'needs', 'nsubj'),
#   ('a purse', 'have', 'dobj'),
#   ('a purse', 'is', 'nsubj'),
#   ('a rag', 'is', 'conj'),
#   ('you', 'have', 'nsubj'),
#   ('something', 'have', 'dobj'),
#   ('it', 'in', 'pobj')],
#  [('passengers', 'get', 'nsubj'),
#   ('nights', 'of', 'pobj'),
#   ('themselves', 'enjoy', 'dobj'),
#   ('a general thing', 'as', 'pobj'),
#   ('I', 'go', 'nsubj'),
#   ('a passenger', 'as', 'pobj'),
#   ('I', 'am', 'nsubj'),
#   ('something', 'am', 'attr'),
#   ('a salt', 'of', 'pobj'),
#   ('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a Commodore', 'as', 'pobj'),
#   ('a Captain', 'Commodore', 'conj'),
#   ('a Cook', 'Captain', 'conj')],
#  [('I', 'abandon', 'nsubj'),
#   ('the glory', 'abandon', 'dobj'),
#   ('distinction', 'glory', 'conj'),
#   ('such offices', 'of', 'pobj'),
#   ('who', 'like', 'nsubj'),
#   ('them', 'like', 'dobj')],
#  [('my part', 'For', 'pobj'),
#   ('I', 'abominate', 'nsubj'),
#   ('every kind', 'of', 'pobj')],
#  [('It', 'is', 'nsubj'),
#   ('I', 'do', 'nsubj'),
#   ('care', 'take', 'dobj'),
#   ('myself', 'of', 'pobj'),
#   ('care', 'taking', 'dobj'),
#   ('ships', 'of', 'pobj'),
#   ('barques', 'ships', 'conj'),
#   ('brigs', 'barques', 'conj'),
#   ('schooners', 'brigs', 'conj'),
#   ('what', 'schooners', 'conj')],
#  [('cook', 'as', 'pobj'),
#   ('I', 'confess', 'nsubj'),
#   ('considerable glory', 'is', 'attr'),
#   ('a cook', 'glory', 'appos'),
#   ('a sort', 'being', 'attr'),
#   ('officer', 'of', 'pobj'),
#   ('ship - board', 'on', 'pobj'),
#   ('I', 'fancied', 'nsubj'),
#   ('broiling fowls', 'fancied', 'dobj'),
#   ('no one', 'is', 'attr'),
#   ('who', 'speak', 'nsubj'),
#   ('a broiled fowl', 'of', 'pobj'),
#   ('I', 'will', 'nsubj')],
#  [('It', 'is', 'nsubj'),
#   ('the idolatrous dotings', 'of', 'pobj'),
#   ('the old Egyptians', 'of', 'pobj'),
#   ('broiled ibis', 'upon', 'pobj'),
#   ('roasted river horse', 'ibis', 'conj'),
#   ('you', 'see', 'nsubj'),
#   ('the mummies', 'see', 'dobj'),
#   ('those creatures', 'of', 'pobj'),
#   ('their huge bake - houses', 'in', 'pobj'),
#   ('the pyramids', 'mummies', 'appos')],
#  [('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('I', 'go', 'nsubj'),
#   ('a simple sailor', 'as', 'pobj'),
#   ('the mast', 'before', 'pobj'),
#   ('the forecastle', 'into', 'pobj'),
#   ('the royal mast - head', 'to', 'pobj')],
#  [('they', 'order', 'nsubj'),
#   ('me', 'order', 'dobj'),
#   ('me', 'jump', 'nsubj'),
#   ('spar', 'from', 'pobj'),
#   ('spar', 'to', 'pobj'),
#   ('a grasshopper', 'like', 'pobj'),
#   ('a May meadow', 'in', 'pobj')],
#  [('this sort', 'is', 'nsubj'), ('thing', 'of', 'pobj')],
#  [('It', 'touches', 'nsubj'),
#   ("one ' s sense", 'touches', 'dobj'),
#   ('honour', 'of', 'pobj'),
#   ('you', 'come', 'nsubj'),
#   ('an old established family', 'of', 'pobj'),
#   ('the land', 'in', 'pobj'),
#   ('the Van Rensselaers', 'family', 'appos'),
#   ('Randolphs', 'Rensselaers', 'conj'),
#   ('Hardicanutes', 'Randolphs', 'conj')],
#  [('your hand', 'putting', 'dobj'),
#   ('the tar - pot', 'into', 'pobj'),
#   ('you', 'lording', 'nsubj'),
#   ('it', 'lording', 'dobj'),
#   ('a country schoolmaster', 'as', 'pobj'),
#   ('the tallest boys', 'stand', 'nsubj'),
#   ('awe', 'in', 'pobj'),
#   ('you', 'of', 'pobj')],
#  [('The transition', 'is', 'nsubj'),
#   ('a keen one', 'is', 'attr'),
#   ('I', 'assure', 'nsubj'),
#   ('you', 'assure', 'dobj'),
#   ('a schoolmaster', 'from', 'pobj'),
#   ('a sailor', 'to', 'pobj'),
#   ('a strong decoction', 'requires', 'dobj'),
#   ('Seneca', 'of', 'pobj'),
#   ('the Stoics', 'Seneca', 'conj'),
#   ('you', 'enable', 'dobj'),
#   ('grin', 'to', 'pobj'),
#   ('it', 'bear', 'dobj')],
#  [('time', 'in', 'pobj')],
#  [('What', 'What', 'ROOT'),
#   ('it', 'of', 'pobj'),
#   ('some old hunks', 'get', 'nsubj'),
#   ('a sea - captain orders', 'of', 'pobj'),
#   ('a broom', 'get', 'dobj'),
#   ('the decks', 'sweep', 'dobj')],
#  [('What', 'of', 'pobj'),
#   ('I', 'mean', 'nsubj'),
#   ('the New Testament', 'of', 'pobj')],
#  [('you', 'think', 'nsubj'),
#   ('the archangel', 'thinks', 'nsubj'),
#   ('Gabriel', 'archangel', 'appos'),
#   ('anything', 'less', 'nsubj'),
#   ('me', 'of', 'pobj'),
#   ('I', 'obey', 'nsubj'),
#   ('that old hunks', 'obey', 'dobj'),
#   ('that particular instance', 'in', 'pobj')],
#  [("' t", 'ain', 'appos'), ('a slave', 'ain', 'appos')],
#  [('me', 'Tell', 'dative')],
#  [('the old sea - captains', 'order', 'nsubj'),
#   ('me', 'order', 'dobj'),
#   ('they', 'thump', 'nsubj'),
#   ('me', 'punch', 'dobj'),
#   ('I', 'have', 'nsubj'),
#   ('the satisfaction', 'have', 'dobj'),
#   ('it', 'is', 'nsubj'),
#   ('everybody', 'is', 'nsubj'),
#   ('one way', 'is', 'attr'),
#   ('much the same way', 'in', 'pobj'),
#   ('a physical or metaphysical point', 'in', 'pobj'),
#   ('view', 'of', 'pobj'),
#   ('the universal thump', 'passed', 'nsubjpass'),
#   ('all hands', 'rub', 'nsubj'),
#   ("each other ' s shoulder - blades", 'rub', 'dobj')],
#  [('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a sailor', 'as', 'pobj'),
#   ('they', 'make', 'nsubj'),
#   ('a point', 'make', 'dobj'),
#   ('me', 'paying', 'dobj'),
#   ('my trouble', 'for', 'pobj'),
#   ('they', 'pay', 'nsubj'),
#   ('passengers', 'pay', 'dative'),
#   ('a single penny', 'pay', 'dobj'),
#   ('I', 'heard', 'nsubj')],
#  [('the contrary', 'On', 'pobj'),
#   ('passengers', 'pay', 'nsubj'),
#   ('themselves', 'passengers', 'appos')],
#  [('all the difference', 'is', 'attr'), ('the world', 'in', 'pobj')],
#  [('The act', 'is', 'nsubj'),
#   ('the most uncomfortable infliction', 'is', 'attr'),
#   ('the two orchard thieves', 'entailed', 'nsubj'),
#   ('us', 'upon', 'pobj')],
#  [('But BEING PAID', 'PAID', 'ROOT'),
#   ('what', 'compare', 'nsubj'),
#   ('it', 'with', 'pobj')],
#  [('The urbane activity', 'is', 'nsubj'),
#   ('a man', 'receives', 'nsubj'),
#   ('money', 'receives', 'dobj'),
#   ('we', 'believe', 'nsubj'),
#   ('money', 'believe', 'dobj'),
#   ('the root', 'be', 'attr'),
#   ('all earthly ills', 'of', 'pobj'),
#   ('no account', 'on', 'pobj'),
#   ('a monied man', 'enter', 'nsubj'),
#   ('heaven', 'enter', 'dobj')],
#  [],
#  [('we', 'consign', 'nsubj'),
#   ('ourselves', 'consign', 'dobj'),
#   ('perdition', 'to', 'pobj')],
#  [('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a sailor', 'as', 'pobj'),
#   ('the wholesome exercise', 'because', 'pobj'),
#   ('pure air', 'exercise', 'conj'),
#   ('the fore - castle deck', 'of', 'pobj')],
#  [('this world', 'in', 'pobj'),
#   ('head winds', 'are', 'nsubj'),
#   ('winds', 'than', 'pobj'),
#   ('astern', 'from', 'pobj'),
#   ('you', 'violate', 'nsubj'),
#   ('the Pythagorean maxim', 'violate', 'dobj'),
#   ('the most part', 'for', 'pobj'),
#   ('the Commodore', 'gets', 'nsubj'),
#   ('the quarter - deck', 'on', 'pobj'),
#   ('his atmosphere', 'gets', 'dobj'),
#   ('second hand', 'at', 'pobj'),
#   ('the sailors', 'from', 'pobj'),
#   ('the forecastle', 'on', 'pobj')],
#  [('He', 'thinks', 'nsubj'),
#   ('he', 'breathes', 'nsubj'),
#   ('it', 'breathes', 'dobj')],
#  [('much the same way', 'In', 'pobj'),
#   ('the commonalty', 'lead', 'nsubj'),
#   ('their leaders', 'lead', 'dobj'),
#   ('many other things', 'in', 'pobj'),
#   ('the same time', 'at', 'pobj'),
#   ('the leaders', 'suspect', 'nsubj'),
#   ('it', 'suspect', 'dobj')],
#  [('it', 'was', 'nsubj'),
#   ('the sea', 'smelt', 'dobj'),
#   ('a merchant sailor', 'as', 'pobj'),
#   ('I', 'take', 'nsubj'),
#   ('it', 'take', 'dobj'),
#   ('my head', 'into', 'pobj'),
#   ('a whaling voyage', 'on', 'pobj'),
#   ('the Fates', 'of', 'pobj'),
#   ('who', 'has', 'nsubj'),
#   ('the constant surveillance', 'has', 'dobj'),
#   ('me', 'of', 'pobj'),
#   ('me', 'dogs', 'dobj'),
#   ('me', 'influences', 'dobj'),
#   ('some unaccountable way', 'in', 'pobj'),
#   ('he', 'answer', 'nsubj'),
#   ('any one', 'than', 'pobj')],
#  [('this whaling voyage', 'on', 'pobj'),
#   ('part', 'formed', 'dobj'),
#   ('the grand programme', 'of', 'pobj'),
#   ('Providence', 'of', 'pobj')],
#  [('It', 'came', 'nsubj'),
#   ('a sort', 'as', 'pobj'),
#   ('brief interlude', 'of', 'pobj'),
#   ('solo', 'interlude', 'conj'),
#   ('more extensive performances', 'between', 'pobj')],
#  [('I', 'take', 'nsubj'),
#   ('it', 'take', 'dobj'),
#   ('this part', 'run', 'nsubj'),
#   ('the bill', 'of', 'pobj'),
#   ('something', 'run', 'dobj')],
#  [('GRAND', 'CONTESTED', 'nsubj'),
#   ('ELECTION', 'CONTESTED', 'dobj'),
#   ('THE PRESIDENCY', 'FOR', 'pobj'),
#   ('THE UNITED STATES', 'OF', 'pobj')],
#  [('" WHALING VOYAGE', 'VOYAGE', 'ROOT'), ('ONE ISHMAEL', 'BY', 'pobj')],
#  [('" BLOODY BATTLE', 'BATTLE', 'ROOT'), ('AFFGHANISTAN', 'IN', 'pobj')],
#  [('I', 'tell', 'nsubj'),
#   ('it', 'was', 'nsubj'),
#   ('those stage managers', 'put', 'nsubj'),
#   ('the Fates', 'managers', 'appos'),
#   ('me', 'put', 'dobj'),
#   ('this shabby part', 'for', 'pobj'),
#   ('a whaling voyage', 'of', 'pobj'),
#   ('others', 'set', 'nsubjpass'),
#   ('magnificent parts', 'for', 'pobj'),
#   ('high tragedies', 'in', 'pobj'),
#   ('genteel comedies', 'in', 'pobj'),
#   ('farces', 'in', 'pobj'),
#   ('I', 'tell', 'nsubj'),
#   ('I', 'recall', 'nsubj'),
#   ('all the circumstances', 'recall', 'dobj'),
#   ('I', 'think', 'nsubj'),
#   ('I', 'see', 'nsubj'),
#   ('the springs', 'into', 'pobj'),
#   ('motives', 'springs', 'conj'),
#   ('me', 'to', 'pobj'),
#   ('various disguises', 'under', 'pobj'),
#   ('me', 'induced', 'dobj'),
#   ('the part', 'performing', 'dobj'),
#   ('I', 'did', 'nsubj'),
#   ('me', 'cajoling', 'dobj'),
#   ('the delusion', 'into', 'pobj'),
#   ('it', 'was', 'nsubj'),
#   ('a choice', 'was', 'attr'),
#   ('my own unbiased freewill', 'from', 'pobj'),
#   ('judgment', 'discriminating', 'dobj')],
#  [('Chief', 'was', 'nsubj'),
#   ('these motives', 'among', 'pobj'),
#   ('the overwhelming idea', 'was', 'attr'),
#   ('the great whale', 'of', 'pobj'),
#   ('himself', 'whale', 'appos')],
#  [('Such a portentous and mysterious monster', 'roused', 'nsubj'),
#   ('all my curiosity', 'roused', 'dobj')],
#  [('he', 'rolled', 'nsubj'),
#   ('his island bulk', 'rolled', 'dobj'),
#   ('the undeliverable , nameless perils', 'seas', 'appos'),
#   ('the whale', 'of', 'pobj'),
#   ('all the attending marvels', 'with', 'pobj'),
#   ('a thousand Patagonian sights', 'of', 'pobj'),
#   ('sounds', 'marvels', 'conj'),
#   ('me', 'sway', 'dobj'),
#   ('my wish', 'to', 'pobj')],
#  [('other men', 'With', 'pobj'),
#   ('such things', 'been', 'nsubj'),
#   ('inducements', 'been', 'attr'),
#   ('me', 'for', 'pobj'),
#   ('I', 'tormented', 'nsubjpass'),
#   ('an everlasting itch', 'with', 'pobj'),
#   ('things', 'for', 'pobj')]]

# %% [markdown]
# ## Exercise
# How does Melville describe nouns? Extract all the pairs related by `amod`.

# %%
# Melville is the author of moby_dick

for sentence in documents[:100]:
  for token in nlp(sentence):
    if token.dep_ == 'amod' : 
      print(token.text, "--> ", token.head.text)
# Out:
# little -->  money
# particular -->  nothing
# watery -->  part
# upper -->  hand
# strong -->  principle
# moral -->  principle
# high -->  time
# philosophical -->  flourish
# surprising -->  nothing
# same -->  feelings
# insular -->  city
# Indian -->  isles
# coral -->  reefs
# extreme -->  downtown
# noble -->  mole
# few -->  hours
# dreamy -->  afternoon
# silent -->  sentinels
# mortal -->  men
# high -->  aloft
# better -->  peep
# green -->  fields
# more -->  crowds
# extremest -->  limit
# shady -->  lee
# magnetic -->  virtue
# high -->  land
# absent -->  minded
# deepest -->  reveries
# great -->  desert
# American -->  desert
# metaphysical -->  professor
# dreamiest -->  quietest
# shadiest -->  quietest
# enchanting -->  bit
# romantic -->  landscape
# chief -->  element
# hollow -->  trunk
# sleepy -->  smoke
# distant -->  woodlands
# overlapping -->  spurs
# magic -->  stream
# poor -->  poet
# healthy -->  boy
# healthy -->  soul
# crazy -->  at
# first -->  voyage
# mystical -->  vibration
# old -->  Persians
# separate -->  deity
# own -->  brother
# mild -->  image
# same -->  image
# ungraspable -->  phantom
# general -->  thing
# such -->  offices
# respectable -->  toils
# considerable -->  glory
# broiled -->  fowl
# idolatrous -->  dotings
# old -->  Egyptians
# broiled -->  ibis
# roasted -->  horse
# huge -->  houses
# simple -->  sailor
# royal -->  head
# old -->  family
# established -->  family
# tallest -->  boys
# keen -->  one
# strong -->  decoction
# old -->  hunks
# old -->  hunks
# particular -->  instance
# old -->  captains
# same -->  way
# physical -->  point
# universal -->  thump
# single -->  penny
# uncomfortable -->  infliction
# earthly -->  ills
# monied -->  man
# wholesome -->  exercise
# pure -->  air
# fore -->  castle
# Pythagorean -->  maxim
# most -->  part
# second -->  hand
# same -->  way
# many -->  things
# other -->  things
# same -->  time
# whaling -->  voyage
# invisible -->  officer
# constant -->  surveillance
# unaccountable -->  way
# whaling -->  voyage
# grand -->  programme
# long -->  time
# brief -->  interlude
# extensive -->  performances
# BLOODY -->  BATTLE
# shabby -->  part
# whaling -->  voyage
# magnificent -->  parts
# high -->  tragedies
# short -->  parts
# genteel -->  comedies
# jolly -->  parts
# various -->  disguises
# own -->  freewill
# unbiased -->  freewill
# overwhelming -->  idea
# great -->  whale
# portentous -->  monster
# wild -->  seas
# undeliverable -->  perils
# attending -->  marvels
# Patagonian -->  sights
# other -->  men
# such -->  things
# everlasting -->  itch
# remote -->  things

# %% [markdown]
# How does he describe men?

# %%
# your code here

for sentence in documents:
  for token in nlp(sentence):
    if token.head.text == 'men' and token.dep_ == 'amod': 
      print(token.text, "--> ", token.head.text)
# Out:
# mortal -->  men
# other -->  men
# sinful -->  men
# sinful -->  men
# learned -->  men
# other -->  men
# Shipped -->  men
# American -->  men
# hearted -->  men
# intrepid -->  men
# momentous -->  men
# red -->  men
# exact -->  men
# other -->  men
# many -->  men
# romantic -->  men
# young -->  men
# such -->  men
# living -->  men
# deep -->  men
# other -->  men
# most -->  men
# most -->  men
# few -->  men
# extra -->  men
# stronger -->  men
# valiant -->  men
# young -->  men
# more -->  men
# such -->  men
# red -->  men
# deeper -->  men
# first -->  men
# veteran -->  men
# sick -->  men
# moccasined -->  men
# dying -->  men
# such -->  men
# last -->  men
# drowned -->  men
# white -->  men
# dumb -->  men
# stout -->  men
# perched -->  men
# missing -->  men
# brave -->  men
# naked -->  men
# other -->  men

# %% [markdown]
# # Try on the language that you prefer!
#
# https://spacy.io/models
